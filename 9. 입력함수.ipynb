# %% [markdown]
# ## 입력함수: input()
# - 사용자에게 입력받아 문자열 값으로 반환하는 함수

# %%
name = input("이름을 입력하세요\n")
# Out:
# 이름을 입력하세요
#  홍길동

# %%
name
# Out:
# '홍길동'

# %%
# 두 수를 전달 받아서 두 수의 합을 알려주는 로직
num1 = int(input("첫 번째 정수 입력:\nex)20\n"))
num2 = int(input("두 번째 정수 입력:\nex)20\n"))
result = f"두 수의 합은: {num1 + num2}"

print(result)
# Out:
# 첫 번째 정수 입력:
# ex)20
#  50
# 두 번째 정수 입력:
# ex)20
#  6
# 두 수의 합은: 56

# %%
# 두 수를 전달 받아서 두 수의 합을 알려주는 로직
num1 = float(input("첫 번째 정수 입력:\nex)20\n"))
num2 = float(input("두 번째 정수 입력:\nex)20\n"))
total = int(num1 + num2)
result = f"두 수의 합은: {total}"

print(result)
# Out:
# 첫 번째 정수 입력:
# ex)20
#  1.6
# 두 번째 정수 입력:
# ex)20
#  6.5
# 두 수의 합은: 8
