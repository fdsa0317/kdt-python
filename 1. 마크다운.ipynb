# %%
print("Hello, World!😊")
# Out:
# Hello, World!😊

# %% [markdown]
# # 주피터 노트북 단축키
# - 코드셀 변경: [ESC] -> [Y]
# - 텍스트셀 변경: [ESC] -> [M]
# - 셀 실행: [Ctrl] + [Enter]
# - 셀 실행 후 코드셀 생성: [Alt] + [Enter]
# - 주석: [Ctrl] + [/]
# - 되돌리기: [Ctrl] + [Z]
# - 다시 되돌리기: [Ctrl] + [Shift] + [Z]
# - 한 줄 삭제: [Ctrl] + [D]
# - 한 줄 복사: [Alt] + [Shift] + [화살표 위 또는 아래]

# %% [markdown]
# # 마크다운(Markdown)
#    - 일반 텍스트 기반의 경량 마크업 언어로 웹표준이 아닌 언어이다.
#    마크업 언어란, 태그 등을 이용하여 문서나 데이터의 구조 등을 기술하며,
#    텍스트만으로 서식이 있는 문서들을 작성할 때 자주 사용된다. 또한 다른 마크업 언어들에 비해
#    문법이 쉽고 간단하여 HTML 등의 서식 문서들로 쉽게 변환되기 때문에 README 파일이나 온라인 게시물 등에 사용된다.

# %% [markdown]
# # 목차(header)
# # : h1
# ## : h2
# ### : h3
# #### : h4
# ##### : h5
# ###### : h6

# %% [markdown]
# # 리스트(list)
# 1. 장점
#     - 간편하고 쉽다
#     - 다양한 플랫폼에서 지원한다.
#
# 2. 단점
#     * 표준이 아니다.
#     * 표현매체마다 다르게 보인다.
#     * 모든 HTML을 대체하지 못하는 단점을 가지고 있다.

# %% [markdown]
# # 용어
# - [] : 대괄호(브레이킷)
# - {} : 중괄호(컬리 브레이킷)
# - () : 소괄호
#
# ## 줄바꿈
# - 띄어쓰기(공백문자) 2개 적으면 줄바꿈
# - <br /> 태그를 사용하여 줄바꿈
# - ex) 파이썬 귀도반 로섬이 좋아하는 코미디언의 이름은<br />몬티 파이썬이다.

# %% [markdown]
# # 표현식
# 1. *내용*: 글자 기울이기(italic)
#    - 파이썬은 퀴도반 로섬이 *좋아하는 코미디언의 이름*을 따서 만든 이름이다.
# 2. **내용**: 글자 굵게(bold)
#     - 파이썬의 로고는 **그리스 로마 신화의 뱀**을 의미하여 생긴 로고이다.
# 3. ~~내용~~ (~ 두 개): 취소선(line through)
#     - ~~C언어~~로 2년 걸린 프로젝트를 파이썬으로 한 달만에 마무리 했다.
# 4. `내용`: 강조(back tick)
#     - 파이썬의 부모 언어는 `C언어`이다. 즉, 파이썬은 C언어에서 파생되었다.

# %% [markdown]
# # 태그(Tag,Element)
# - 여는 태그: <태그명>, 태그의 시작을 알리는 태그
# - 닫는 태그: </태그명>, 태그의 종료를 알리는 태그
# - 내용: <태그명>내용</태그명>, 태그가 표현하는 컨텐츠
#
# - ex) <sup>홍길동</sup>
# - <img style="width:200px;" src="https://search.pstatic.net/sunny/?src=https%3A%2F%2Fdcimg1.dcinside.com%2Fviewimage.php%3Fno%3D24b0d769e1d32ca73fee86fa11d028310f26c7ac70778cce12f3e45987e7e89609c7a1af9b7653ab28123bee67df5377972444fa760cb48a892c6419c8f63b30cc3235a17f76dc6e0d3aae&type=a340" />

# %% [markdown]
# # 하이퍼 링크
# - [구글](주소)
# - [구글](https://www.google.com/)
# - ![이미지](주소)
# - ![이미지](https://search.pstatic.net/sunny/?src=https%3A%2F%2Fdcimg1.dcinside.com%2Fviewimage.php%3Fno%3D24b0d769e1d32ca73fee86fa11d028310f26c7ac70778cce12f3e45987e7e89609c7a1af9b7653ab28123bee67df5377972444fa760cb48a892c6419c8f63b30cc3235a17f76dc6e0d3aae&type=a340)

# %% [markdown]
# # 라인
# ---
# 선
# <hr />
# 선

# %% [markdown]
# # 인용문
# - 남의 말이나 글을 직접 또는 간접적으로 따온 문장을 인용문장이라고 합니다.
#
# > 인용문
# >> 중첩 인용문
# >>> 증첩 인용문2
# >>>> 중첩 인용문3

# %% [markdown]
# # 표(table)
# - 행과 열로 존재한다. 흔히 표의 형식으로 구성된 것을 테이블이라고 한다.
#
# |번호|이름|
# |----|----|
# |001|홍길동|
# |002|장보고|
# |003|이순신|

# %% [markdown]
# # 레이택(LaTex)
# - 수학과 과학 공식이 포함된 전문적인 문서를 작성할 때 사용한다.
# - $내용$
# - $x + y =z$
# <!-- \: 역슬래시 -->
# - $\alpha$
# - $\sigma$
