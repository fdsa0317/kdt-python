# %%
import requests
from bs4 import BeautifulSoup as bs
import json

# %%
# https://jsonplaceholder.typicode.com/users
ur1 = "https://jsonplaceholder.typicode.com/users"
response = requests.get(ur1)

print(response.text)
# Out:
# [
#   {
#     "id": 1,
#     "name": "Leanne Graham",
#     "username": "Bret",
#     "email": "Sincere@april.biz",
#     "address": {
#       "street": "Kulas Light",
#       "suite": "Apt. 556",
#       "city": "Gwenborough",
#       "zipcode": "92998-3874",
#       "geo": {
#         "lat": "-37.3159",
#         "lng": "81.1496"
#       }
#     },
#     "phone": "1-770-736-8031 x56442",
#     "website": "hildegard.org",
#     "company": {
#       "name": "Romaguera-Crona",
#       "catchPhrase": "Multi-layered client-server neural-net",
#       "bs": "harness real-time e-markets"
#     }
#   },
#   {
#     "id": 2,
#     "name": "Ervin Howell",
#     "username": "Antonette",
#     "email": "Shanna@melissa.tv",
#     "address": {
#       "street": "Victor Plains",
#       "suite": "Suite 879",
#       "city": "Wisokyburgh",
#       "zipcode": "90566-7771",
#       "geo": {
#         "lat": "-43.9509",
#         "lng": "-34.4618"
#       }
#     },
#     "phone": "010-692-6593 x09125",
#     "website": "anastasia.net",
#     "company": {
#       "name": "Deckow-Crist",
#       "catchPhrase": "Proactive didactic contingency",
#       "bs": "synergize scalable supply-chains"
#     }
#   },
#   {
#     "id": 3,
#     "name": "Clementine Bauch",
#     "username": "Samantha",
#     "email": "Nathan@yesenia.net",
#     "address": {
#       "street": "Douglas Extension",
#       "suite": "Suite 847",
#       "city": "McKenziehaven",
#       "zipcode": "59590-4157",
#       "geo": {
#         "lat": "-68.6102",
#         "lng": "-47.0653"
#       }
#     },
#     "phone": "1-463-123-4447",
#     "website": "ramiro.info",
#     "company": {
#       "name": "Romaguera-Jacobson",
#       "catchPhrase": "Face to face bifurcated interface",
#       "bs": "e-enable strategic applications"
#     }
#   },
#   {
#     "id": 4,
#     "name": "Patricia Lebsack",
#     "username": "Karianne",
#     "email": "Julianne.OConner@kory.org",
#     "address": {
#       "street": "Hoeger Mall",
#       "suite": "Apt. 692",
#       "city": "South Elvis",
#       "zipcode": "53919-4257",
#       "geo": {
#         "lat": "29.4572",
#         "lng": "-164.2990"
#       }
#     },
#     "phone": "493-170-9623 x156",
#     "website": "kale.biz",
#     "company": {
#       "name": "Robel-Corkery",
#       "catchPhrase": "Multi-tiered zero tolerance productivity",
#       "bs": "transition cutting-edge web services"
#     }
#   },
#   {
#     "id": 5,
#     "name": "Chelsey Dietrich",
#     "username": "Kamren",
#     "email": "Lucio_Hettinger@annie.ca",
#     "address": {
#       "street": "Skiles Walks",
#       "suite": "Suite 351",
#       "city": "Roscoeview",
#       "zipcode": "33263",
#       "geo": {
#         "lat": "-31.8129",
#         "lng": "62.5342"
#       }
#     },
#     "phone": "(254)954-1289",
#     "website": "demarco.info",
#     "company": {
#       "name": "Keebler LLC",
#       "catchPhrase": "User-centric fault-tolerant solution",
#       "bs": "revolutionize end-to-end systems"
#     }
#   },
#   {
#     "id": 6,
#     "name": "Mrs. Dennis Schulist",
#     "username": "Leopoldo_Corkery",
#     "email": "Karley_Dach@jasper.info",
#     "address": {
#       "street": "Norberto Crossing",
#       "suite": "Apt. 950",
#       "city": "South Christy",
#       "zipcode": "23505-1337",
#       "geo": {
#         "lat": "-71.4197",
#         "lng": "71.7478"
#       }
#     },
#     "phone": "1-477-935-8478 x6430",
#     "website": "ola.org",
#     "company": {
#       "name": "Considine-Lockman",
#       "catchPhrase": "Synchronised bottom-line interface",
#       "bs": "e-enable innovative applications"
#     }
#   },
#   {
#     "id": 7,
#     "name": "Kurtis Weissnat",
#     "username": "Elwyn.Skiles",
#     "email": "Telly.Hoeger@billy.biz",
#     "address": {
#       "street": "Rex Trail",
#       "suite": "Suite 280",
#       "city": "Howemouth",
#       "zipcode": "58804-1099",
#       "geo": {
#         "lat": "24.8918",
#         "lng": "21.8984"
#       }
#     },
#     "phone": "210.067.6132",
#     "website": "elvis.io",
#     "company": {
#       "name": "Johns Group",
#       "catchPhrase": "Configurable multimedia task-force",
#       "bs": "generate enterprise e-tailers"
#     }
#   },
#   {
#     "id": 8,
#     "name": "Nicholas Runolfsdottir V",
#     "username": "Maxime_Nienow",
#     "email": "Sherwood@rosamond.me",
#     "address": {
#       "street": "Ellsworth Summit",
#       "suite": "Suite 729",
#       "city": "Aliyaview",
#       "zipcode": "45169",
#       "geo": {
#         "lat": "-14.3990",
#         "lng": "-120.7677"
#       }
#     },
#     "phone": "586.493.6943 x140",
#     "website": "jacynthe.com",
#     "company": {
#       "name": "Abernathy Group",
#       "catchPhrase": "Implemented secondary concept",
#       "bs": "e-enable extensible e-tailers"
#     }
#   },
#   {
#     "id": 9,
#     "name": "Glenna Reichert",
#     "username": "Delphine",
#     "email": "Chaim_McDermott@dana.io",
#     "address": {
#       "street": "Dayna Park",
#       "suite": "Suite 449",
#       "city": "Bartholomebury",
#       "zipcode": "76495-3109",
#       "geo": {
#         "lat": "24.6463",
#         "lng": "-168.8889"
#       }
#     },
#     "phone": "(775)976-6794 x41206",
#     "website": "conrad.com",
#     "company": {
#       "name": "Yost and Sons",
#       "catchPhrase": "Switchable contextually-based project",
#       "bs": "aggregate real-time technologies"
#     }
#   },
#   {
#     "id": 10,
#     "name": "Clementina DuBuque",
#     "username": "Moriah.Stanton",
#     "email": "Rey.Padberg@karina.biz",
#     "address": {
#       "street": "Kattie Turnpike",
#       "suite": "Suite 198",
#       "city": "Lebsackbury",
#       "zipcode": "31428-2261",
#       "geo": {
#         "lat": "-38.2386",
#         "lng": "57.2232"
#       }
#     },
#     "phone": "024-648-3804",
#     "website": "ambrose.net",
#     "company": {
#       "name": "Hoeger LLC",
#       "catchPhrase": "Centralized empowering task-force",
#       "bs": "target end-to-end models"
#     }
#   }
# ]

# %%
print(type(response.text))
# Out:
# <class 'str'>

# %%
datas = json.loads(response.text)
print(type(datas))
print(datas[0])
# Out:
# <class 'list'>
# {'id': 1, 'name': 'Leanne Graham', 'username': 'Bret', 'email': 'Sincere@april.biz', 'address': {'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}, 'phone': '1-770-736-8031 x56442', 'website': 'hildegard.org', 'company': {'name': 'Romaguera-Crona', 'catchPhrase': 'Multi-layered client-server neural-net', 'bs': 'harness real-time e-markets'}}

# %% [markdown]
# ## 직렬화
# - python 객체 -> json 객체로 변환

# %% [markdown]
# ## 역직렬화
# - json 객체 -> python 객체로 변환

# %%
# 역직렬화
datas = json.loads(response.text)
print(type(datas))
# 직렬화
json_datas = json.dumps(datas)
json_datas
# Out:
# <class 'list'>
# '[{"id": 1, "name": "Leanne Graham", "username": "Bret", "email": "Sincere@april.biz", "address": {"street": "Kulas Light", "suite": "Apt. 556", "city": "Gwenborough", "zipcode": "92998-3874", "geo": {"lat": "-37.3159", "lng": "81.1496"}}, "phone": "1-770-736-8031 x56442", "website": "hildegard.org", "company": {"name": "Romaguera-Crona", "catchPhrase": "Multi-layered client-server neural-net", "bs": "harness real-time e-markets"}}, {"id": 2, "name": "Ervin Howell", "username": "Antonette", "email": "Shanna@melissa.tv", "address": {"street": "Victor Plains", "suite": "Suite 879", "city": "Wisokyburgh", "zipcode": "90566-7771", "geo": {"lat": "-43.9509", "lng": "-34.4618"}}, "phone": "010-692-6593 x09125", "website": "anastasia.net", "company": {"name": "Deckow-Crist", "catchPhrase": "Proactive didactic contingency", "bs": "synergize scalable supply-chains"}}, {"id": 3, "name": "Clementine Bauch", "username": "Samantha", "email": "Nathan@yesenia.net", "address": {"street": "Douglas Extension", "suite": "Suite 847", "city": "McKenziehaven", "zipcode": "59590-4157", "geo": {"lat": "-68.6102", "lng": "-47.0653"}}, "phone": "1-463-123-4447", "website": "ramiro.info", "company": {"name": "Romaguera-Jacobson", "catchPhrase": "Face to face bifurcated interface", "bs": "e-enable strategic applications"}}, {"id": 4, "name": "Patricia Lebsack", "username": "Karianne", "email": "Julianne.OConner@kory.org", "address": {"street": "Hoeger Mall", "suite": "Apt. 692", "city": "South Elvis", "zipcode": "53919-4257", "geo": {"lat": "29.4572", "lng": "-164.2990"}}, "phone": "493-170-9623 x156", "website": "kale.biz", "company": {"name": "Robel-Corkery", "catchPhrase": "Multi-tiered zero tolerance productivity", "bs": "transition cutting-edge web services"}}, {"id": 5, "name": "Chelsey Dietrich", "username": "Kamren", "email": "Lucio_Hettinger@annie.ca", "address": {"street": "Skiles Walks", "suite": "Suite 351", "city": "Roscoeview", "zipcode": "33263", "geo": {"lat": "-31.8129", "lng": "62.5342"}}, "phone": "(254)954-1289", "website": "demarco.info", "company": {"name": "Keebler LLC", "catchPhrase": "User-centric fault-tolerant solution", "bs": "revolutionize end-to-end systems"}}, {"id": 6, "name": "Mrs. Dennis Schulist", "username": "Leopoldo_Corkery", "email": "Karley_Dach@jasper.info", "address": {"street": "Norberto Crossing", "suite": "Apt. 950", "city": "South Christy", "zipcode": "23505-1337", "geo": {"lat": "-71.4197", "lng": "71.7478"}}, "phone": "1-477-935-8478 x6430", "website": "ola.org", "company": {"name": "Considine-Lockman", "catchPhrase": "Synchronised bottom-line interface", "bs": "e-enable innovative applications"}}, {"id": 7, "name": "Kurtis Weissnat", "username": "Elwyn.Skiles", "email": "Telly.Hoeger@billy.biz", "address": {"street": "Rex Trail", "suite": "Suite 280", "city": "Howemouth", "zipcode": "58804-1099", "geo": {"lat": "24.8918", "lng": "21.8984"}}, "phone": "210.067.6132", "website": "elvis.io", "company": {"name": "Johns Group", "catchPhrase": "Configurable multimedia task-force", "bs": "generate enterprise e-tailers"}}, {"id": 8, "name": "Nicholas Runolfsdottir V", "username": "Maxime_Nienow", "email": "Sherwood@rosamond.me", "address": {"street": "Ellsworth Summit", "suite": "Suite 729", "city": "Aliyaview", "zipcode": "45169", "geo": {"lat": "-14.3990", "lng": "-120.7677"}}, "phone": "586.493.6943 x140", "website": "jacynthe.com", "company": {"name": "Abernathy Group", "catchPhrase": "Implemented secondary concept", "bs": "e-enable extensible e-tailers"}}, {"id": 9, "name": "Glenna Reichert", "username": "Delphine", "email": "Chaim_McDermott@dana.io", "address": {"street": "Dayna Park", "suite": "Suite 449", "city": "Bartholomebury", "zipcode": "76495-3109", "geo": {"lat": "24.6463", "lng": "-168.8889"}}, "phone": "(775)976-6794 x41206", "website": "conrad.com", "company": {"name": "Yost and Sons", "catchPhrase": "Switchable contextually-based project", "bs": "aggregate real-time technologies"}}, {"id": 10, " ...

# %%
list(map(lambda data: data["email"].split("@")[0], datas))
# Out:
# ['Sincere',
#  'Shanna',
#  'Nathan',
#  'Julianne.OConner',
#  'Lucio_Hettinger',
#  'Karley_Dach',
#  'Telly.Hoeger',
#  'Sherwood',
#  'Chaim_McDermott',
#  'Rey.Padberg']

# %% [markdown]
# ## Beatifulsoup: html.parser

# %%
tags = """
    <ul>
        <li class='list'>이예나</li>
        <li class='list'>오준승</li>
        <li class='list'>채진성</li>
        <li class='list'>오슬기</li>
    </ul>
"""

# %%
soup = bs(tags, "html.parser")
print(soup)
# Out:
# <ul>
# <li class="list">이예나</li>
# <li class="list">오준승</li>
# <li class="list">채진성</li>
# <li class="list">오슬기</li>
# </ul>

# %%
# .find("태그명", class_="클래스명")
# .find("태그명", id_="아이디명")
# .find("태그명")
li1 = soup.find("li")
print(li1)

li2 = soup.find_all("li")
print(li2)

# .text: 태그의 내용을 가져오는 필드
print(li1.text)
# Out:
# <li class="list">이예나</li>
# [<li class="list">이예나</li>, <li class="list">오준승</li>, <li class="list">채진성</li>, <li class="list">오슬기</li>]
# 이예나

# %%
list(map(lambda tag: tag.text, li2))
# Out:
# ['이예나', '오준승', '채진성', '오슬기']

# %%
tags = """
    <ul>
        <li class='list odd'>이예나</li>
        <li class='list even'>오준승</li>
        <li class='list odd'>채진성</li>
        <li class='list even'>오슬기</li>
        <li class='list odd'>조수민</li>
        <li class='list even'>한혜진</li>
    </ul>
"""

print(tags)
# Out:
#     <ul>
#         <li class='list odd'>이예나</li>
#         <li class='list even'>오준승</li>
#         <li class='list odd'>채진성</li>
#         <li class='list even'>오슬기</li>
#         <li class='list odd'>조수민</li>
#         <li class='list even'>한혜진</li>
#     </ul>

# %%
soup = bs(tags, "html.parser")

soup.find_all("li", class_="even")
# Out:
# [<li class="list even">오준승</li>,
#  <li class="list even">오슬기</li>,
#  <li class="list even">한혜진</li>]

# %% [markdown]
# ## .select()
# - 태그, 클래스(), 아이디를 css 선택자로 선택하는 메서드

# %%
# .select(): 모두 list로 가져옴
soup.select(".list")

# .select_one()
soup.select_one(".list")
# Out:
# <li class="list odd">이예나</li>

# %%
tags = """
    <ul>
        <li id="first" class='list odd'>이예나</li>
        <li class='list even'>오준승</li>
        <li class='list odd'>채진성</li>
        <li class='list even'>오슬기</li>
        <li class='list odd'>조수민</li>
        <li class='list even'>한혜진</li>
    </ul>
"""
print(tags)
# Out:
#     <ul>
#         <li id="first" class='list odd'>이예나</li>
#         <li class='list even'>오준승</li>
#         <li class='list odd'>채진성</li>
#         <li class='list even'>오슬기</li>
#         <li class='list odd'>조수민</li>
#         <li class='list even'>한혜진</li>
#     </ul>

# %%
soup = bs(tags, "html.parser")
soup.select_one("#first")
# Out:
# <li class="list odd" id="first">이예나</li>

# %%
melon_url = "https://www.melon.com/chart/index.htm"

# Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"}
response = requests.get(melon_url, headers=headers)
# response.text

# %%
melon_soup = bs(response.text, "html.parser")
melon_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="4022717807957185" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="멜론" property="og:site_name"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="/favicon.ico?2" id="favicon" rel="shortcut icon" type="image/x-icon"/>
# <link href="/resource/style/web/common/melonweb_layout.css?tm=20260813" rel="stylesheet" type="text/css"/>
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/l8/i/bmqlrmeyi7uljr5.css" rel="stylesheet" type="text/css"/>
# <!-- 댓글 css 파일 네임 변경 -->
# <!--멜론혜택 페이지 댓글 css 예외처리-->
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/1s/q/yjotd8rjsdw4eg.css" rel="stylesheet" type="text/css"/>
# <link href="/resource/style/web/chart/melonweb_chart_4x.css" rel="stylesheet" type="text/css"/>
# <link href="https://static.melon.co.kr/static/web/resource/style/w1/qa/5/rlbqwv6hljdyw.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Nunito:400" rel="stylesheet"/>
# <script src="/resource/script/cds/common/web/member_api.js?_resVer=b4ce10a86ee7524c9e7d2d38ad43a769" type="text/javascript"></script>
# <script src="/resource/script/cds/common/web/commerce_api.js?_resVer=3be4a69429902f23e7b988e16b9090ad" type="text/javascript"></script>
# <script src="/resource/script/web/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="https://member.melon.com/resource/script/web/member/melonweb_member_external.js?tm=20260909" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/c1/d/7j9pwitvgh7.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	(function() {
# 		WEBPOCIMG = {
# 			defaultImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				var thumbType = "_500";
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
#
# 			defaultAlbumImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
#
# 			defaultArtistImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 300;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_300";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noArtist" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultDjImg : function(obj){
# 			},
# 			defaultMvImg : function(obj, width, height){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(height == null || height == '') height = $(obj).height();
#
# 				var ratio43 = Math.floor((4/3)*10)/10;
# 				var ratio169 = Math.floor((16/9)*10)/10;
# 				var ratioObj = Math.floor((width/height)*10)/10;
#
# 				var ratio = "4x3";
# 				if(ratioObj == ratio43){
# 					ratio = "4x3"; //contentsType = "mv43";
# 				} else if(ratioObj == ratio169){
# 					ratio = "16x9"; //contentsType = "mv169";
# 				} else {
# 					if(ratioObj > 1.5) ratio = "16x9";
# 					else ratio = "4x3";
# 				}
#
# 				if(width == 0) width = 640;
# 				if(height == 0) ratio = "16x9";
#
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_" + ratio + "_640";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noMovie" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultPlaylistImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultMemberImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 300;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_300";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noArtist" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultPhotoImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 500;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_500";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultShopImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				if(width == 0) width = 256;
# 				//가장 큰사이즈로 리사이즈함
# 				var thumbType = "_256";
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noProduct" + thumbType + "_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultShowwingImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
#
# 				var thumbType = "_256";
# 				if(width > 0 && width <= 300){
# 					thumbType = "_256";
# 				} else {
# 					thumbType = "_313";//추후 조절값
# 				}
# 				var altSrc = "//cdnimg.melon.co.kr/resource/image/web/default/noShowing" + thumbType + ".jpg";
# 				if(obj.src != altSrc){
# 					obj.src = altSrc;
# 				}
# 			},
# 			defaultTicketImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
#
# 				var thumbType = "_256";
# 				if(width > 0 && width <= 300){
# 					thumbType = "_256";
# 				} else {
# 					thumbType = "_313";//추후 조절값
# 				}
# 				var altSrc = "//cdnimg.melon.co.kr/resource/image/web/default/noTicket" + thumbType + ".png";
# 				if(obj.src != altSrc){
# 					obj.src = altSrc;
# 				}
# 			},
# 			defaultSmartRadioImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noSmartradio_59_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			},
# 			defaultConcertImg : function(obj, width){
# 				if(width == null || width == '') width = $(obj).width();
# 				var defaultImg = "//cdnimg.melon.co.kr/resource/image/web/default/noAlbum_114_160727.jpg/melon/resize/" + width;
# 				if(obj.src != defaultImg){
# 					obj.src = defaultImg;
# 				}
# 			}
# 		}
# 		,WEBELLIPSIS = {
# 			ellipsis : function(ellipsisName,moreClassName,eWidth){
# 		        //아티스트 더보기
# 		        var arObj = $('.' + ellipsisName);
# 		        for(var i = 0; i < arObj.length; i++){
# 		            if (arObj.eq(i).width() > eWidth ){
# 		                arObj.eq(i).parent().parent().parent().find('.' + moreClassName).show();
# 		            }
# 		        }
# 			}
# 		}
# 	})();
# 	</script>
# </head>
# <body>
# <div id="wrap">
# <div id="skip_nav">skip navigation
# 		<ul>
# <li><a href="#gnb_menu">메뉴</a></li>
# <li><a href="#conts_section">본문</a></li>
# <li><a href="#footer">하단 정보</a></li>
# </ul>
# </div>
# <!--  header -->
# <div class="gnb2_expn" id="header">
# <div class="my_fold" id="header_wrap"> <!-- 1024이상 마이영역 접었을때 클래스 my_fold 추가 -->
# <div class="clfix" id="gnb">
# <!-- 상단 빠른 메뉴 -->
# <div id="util_menu">
# <p class="none">상단 빠른 메뉴</p>
# <div class="top_left">
# <ul class="menu-list">
# <li><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V08&amp;ACTION_AF_CLICK=V1" href="//ticket.melon.com/main/index.htm" title="멜론티켓"><span>멜론티켓</span></a></li>
# </ul>
# </div>
# <!-- 140603_수정 -->
# <div class="top_right">
# <ul class="menu-list">
# <li><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B01&amp;ACTION_AF_CLICK=V1" href="/commerce/pamphlet/web/sale_listMainView.htm" title="이용권구매"><span>이용권구매</span></a></li>
# <li><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V06&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/benefit/lounge/main.htm" title="멜론혜택"><span>멜론혜택</span></a></li>
# <li><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=B03&amp;ACTION_AF_CLICK=V1" href="/event/list.htm" title="이벤트"><span>이벤트</span></a></li>
# <li><a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=V02&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/customer/announce/index.htm" title="공지사항"><span>공지사항</span></a></li>
# </ul>
# <script type="text/javascript">
# 							var html = '';
# 							var logoutReturnUrl = window.location.href;
#
# 							if(logoutReturnUrl == ''){
# 								logoutReturnUrl = 'www.melon.com';
# 							}
#
# 							if(isMelonLogin()){
#
# 								var memberKey = getMemberKey()
# 								var memberInfo = svcMember.displayIdByMemberKey(memberKey);
# 								var memberType = svcMember.getMemberType().MEMBERTYPE;
# 								var gradeInfo = svcMember.gradeInfoByMemberKey(memberKey);
#
# 								var memId = '';
# 								if(memberType == undefined || memberType == null){
# 									memberType = '0';
# 								}
#
# 								if(memberInfo.DISPLAYID != undefined || memberInfo.DISPLAYID != null){
# 									memId = memberInfo.DISPLAYID;
# 								}
#
# 								if(memId.indexOf("@") != -1 && memberType != '1'){//카카오계정이 아닌경우에만 @도메인 영역 삭제처리
# 									memId = memId.split("@")[0];
# 								}
#
# 								var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
# 								var fromMPSYn = fromMPS == null || fromMPS.indexOf("MELONPLAYER") < 0;
#
# 								var gradeImg = "";
# 								var gradeName = gradeInfo.GRADE;
#
# 								if(gradeName == undefined || gradeName == null){
# 									gradeName = '일반';
# 								}
#
#
# 								try {
# 									if(gradeName == '일반'){
# 										gradeImg = "";
# 									} else if(gradeName == 'GREEN'){
# 										gradeImg = "<span class=\"icon-comm grade-green\"></span>";
# 									} else if(gradeName == 'SILVER'){
# 										gradeImg = "<span class=\"icon-comm grade-silver\"></span>";
# 									} else if(gradeName == 'GOLD'){
# 										gradeImg = "<span class=\"icon-comm grade-gold\"></span>";
# 									} else if(gradeName == 'VIP'){
# 										gradeImg = "<span class=\"icon-comm grade-vip\"></span>";
# 									} else if(gradeName == 'MVIP'){
# 										gradeImg = "<span class=\"icon-comm grade-mvip\"></span>";
# 									}
#
# 									//카카오연동확인
# 									if(memberType == '1'){
# 										gradeImg += "<span class=\"icon-comm icon-kakao\"></span>";
# 									}
#
# 								} catch (e) {}
#
# 								var logoutButtonHtml = '<button type="button" title="로그아웃" class="btn_top_logout" onclick="javascript:MELON.WEBSVC.POC.logout(\'\');">로그아웃</button>';
#
# 								html = ['<div class="header_login">',
# 									' <span class="icon_grade">',
# 									'' + gradeImg + '',
# 									' </span>',
# 									' <span class="wrap_id"><a href="javascript:location.href=_getHttpsMemberDomain()+ \'/muid/web/help/myinfointro_inform.htm\';" class="user_id"><strong>' + memId + '</strong>님</a></span>',
# 									fromMPSYn ? logoutButtonHtml : '', //멜론 플레이어에서 로그아웃 싱크 안맞는 이슈로 인해 로그아웃 멜론 플레이어에서 왔을 시 버튼 제거
# 									'</div>'
# 								].join('');
# 								document.write(html);
# 							}
# 						</script>
# </div>
# <!-- //140603_수정 -->
# </div>
# <!-- //상단 빠른 메뉴 -->
# <div class="header-utils">
# <h1 class="logo">
# <a class="mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=M01&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/index.htm" title="Melon 홈으로 이동"><span class="screen-out">Melon</span></a>
# </h1>
# <!-- 통합검색 영역 -->
# <fieldset>
# <legend>통합검색영역</legend>
# <input id="top_search" name="" onkeypress="if(event.keyCode == 13){goSearch();}" placeholder="" title="검색 입력 편집창" type="text"/><input id="keywordLink" name="keywordLink" type="hidden" value=""/>
# <button class="btn_icon btn_auto close" id="top_search_autocomplete_toggle" style="display: none;" title="자동검색 펼침" type="button"><span class="odd_span">자동검색 펼침</span></button> <!-- open/close 클래스 사용 -->
# <button class="btn_icon search_m" title="검색" type="button"><span class="odd_span">검색</span></button>
# <div class="auto_complete" id="top_search_autocomplete"><div class="auto_complete_cont" style="display:block;"><!-- 자동완성 레이어 --></div></div>
# <div class="auto_complete" id="top_search_autocomplete_template" style="display: none;"> <!-- 자동완성 레이어 템플릿 -->
# <!-- 텍스트 결과 -->
# <ul class="text_result">
# <li><a class="autocomplete-label" href="#"></a></li>
# </ul>
# <!-- 섬네일 결과 -->
# <ul class="thumb_result">
# <li class="cate"></li>
# <li class="class02">
# <a href="#">
# <span class="thumb_40">
# <span class="thumb_frame"></span>
# <img alt="" class="autocomplete-img" height="40" width="40"/>
# </span>
# <div class="info">
# <span class="autocomplete-label"></span><br/>
# <span><span class="f11 autocomplete-info"></span></span>
# </div>
# </a>
# </li>
# </ul>
# <!-- 검색어가 없을 때 -->
# <ul class="text_result">
# <li class="result_none">
# <span>해당글자로 시작하는 단어가 없습니다.</span>
# </li>
# </ul>
# </div>
# </fieldset>
# <form action="" id="searchFrm" method="get" style="display: none">
# <input name="q" type="hidden"/>
# <input name="section" type="hidden"/>
# </form>
# <!-- //통합검색 영역 -->
# <!-- 실시간 검색어 -->
# <div class="realtime_soar_keyword">
# <!-- 140519_수정 -->
# <a class="title" href="#none">인기 검색어</a>
# <!-- //140519_수정 -->
# <div class="keyword_overlay">
# <ol style="overflow:hidden;">
# </ol>
# <!-- 140423_추가 -->
# <!-- //140423_추가 -->
# </div>
# </div>
# <!-- //실시간 검색어 -->
# <!-- 배너 영역 -->
# <div class="cmn_banner"></div>
# </div>
# </div>
# <!-- 140314_gnb마크업 수정 -->
# <div id="gnb_menu">
# <ul>
# <li class="nth1 on">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=R01&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/chart/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu01">멜론차트</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child on"><a href="//www.melon.com/chart/index.htm"><span class="menu_chart m1">TOP100</span></a></li>
# <li class=""><a href="//www.melon.com/chart/hot100/index.htm"><span class="menu_chart m6">HOT100</span></a></li><!-- // MELONUIT-2465 -->
# <li class=""><a href="//www.melon.com/chart/day/index.htm"><span class="menu_chart m2">일간</span></a></li>
# <li class=""><a href="//www.melon.com/chart/week/index.htm"><span class="menu_chart m3">주간</span></a></li>
# <li class=""><a href="//www.melon.com/chart/month/index.htm"><span class="menu_chart m4">월간</span></a></li>
# <li class=""><a href="//www.melon.com/chart/age/index.htm"><span class="menu_chart m5">시대</span></a></li>
# </ul>
# <div class="chart_finder">
# <button class="btn_chart_f" onclick="location.href='//www.melon.com/chart/search/index.htm'" type="button"><span class="odd_span">차트 파인더</span></button>
# </div>
# </div>
# </li>
# <li class="nth2">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C01&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/new/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu02">최신음악</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/new/index.htm"><span class="menu_new m1">최신곡</span></a></li>
# <li class=""><a href="//www.melon.com/new/album/index.htm"><span class="menu_new m2">최신앨범</span></a></li>
# <li class=""><a href="//www.melon.com/new/mv/index.htm"><span class="menu_new m3">최신 뮤직비디오</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth3">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=C03&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/genre/song_list.htm?gnrCode=GN0100"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu03">장르음악</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/genre/song_list.htm?gnrCode=GN0100"><span class="menu_gnr nm1">한국대중음악</span></a></li>
# <li class=""><a href="//www.melon.com/genre/song_list.htm?gnrCode=GN0900"><span class="menu_gnr nm2">해외POP음악</span></a></li>
# <li class=""><a href="//www.melon.com/genre/song_list.htm?gnrCode=GN1500"><span class="menu_gnr nm3">그외 인기장르</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth4">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S04&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/dj/today/djtoday_list.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu04">멜론DJ</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/dj/today/djtoday_list.htm"><span class="menu_dj m1">투데이</span></a></li>
# <li class=""><a href="//www.melon.com/dj/essential/djessential_list.htm"><span class="menu_dj m2">전문가 선곡</span></a></li>
# <li class=""><a href="//www.melon.com/dj/themegenre/djthemegenre_list.htm"><span class="menu_dj m3">#테마장르</span></a></li>
# <li class=""><a href="//www.melon.com/dj/powerdj/djpowerdj_list.htm"><span class="menu_dj m4">파워DJ</span></a></li>
# <li class=""><a href="//www.melon.com/dj/chart/djchart_list.htm"><span class="menu_dj m5">인기</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth5">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S05&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/tv/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu05">멜론TV</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/tv/index.htm"><span class="menu_tv m1">오늘은 뭘 볼까</span></a></li>
# <li class=""><a href="//www.melon.com/tv/mv/index.htm"><span class="menu_tv m2">뮤직비디오</span></a></li>
# <li class=""><a href="//www.melon.com/tv/menu/index.htm?menuSeq=1"><span class="menu_tv m3">멜론 오리지널</span></a></li>
# <li class=""><a href="//www.melon.com/tv/menu/index.htm?menuSeq=4"><span class="menu_tv m4">아티스트 업데이트</span></a></li>
# <li class=""><a href="//www.melon.com/tv/menu/index.htm?menuSeq=3"><span class="menu_tv m5">방송</span></a></li>
# </ul>
# </div>
# </li>
# <li class="nth6">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S07&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/artistplus/todayupdate/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu06">스타포스트</span></a>
# <div class="lay_menu">
# <ul>
# <li class="first_child"><a href="//www.melon.com/artistplus/todayupdate/index.htm"><span class="menu_arti m1">NOW</span></a></li>
# <li class=""><a href="//www.melon.com/artistplus/artistchart/index.htm"><span class="menu_arti m3">아티스트 랭킹</span></a></li>
# <li class=""><a href="//www.melon.com/artistplus/myranking/index.htm"><span class="menu_arti m4">마이 랭킹</span></a></li>
# </ul>
# <div class="menu_artist_btn">
# <div class="artist_fan">
# <button class="btn_fan" onclick="MELON.WEBSVC.POC.menu.goMyMusicFanSignArtist();" type="button"><span class="odd_span">팬맺은 아티스트</span></button>
# </div>
# <div class="artist_finder">
# <button class="btn_artist_f" onclick="location.href='//www.melon.com/artistplus/finder/index.htm'" type="button"><span class="odd_span">아티스트 파인더</span></button>
# </div>
# </div>
# </div>
# </li>
# <!-- 160314 수정 -->
# <li class="nth7">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S09&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/musicstory/today/index.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu07">매거진</span></a>
# </li>
# <!-- // 160314 수정 -->
# <li class="nth8">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S11&amp;ACTION_AF_CLICK=V1" href="//www.melon.com/melonaward/weekAward.htm"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu08">뮤직어워드</span></a>
# </li>
# <li class="nth11 last_child">
# <a class="cur_menu" href="https://musicwave.melon.com"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu11">뮤직웨이브</span></a>
# </li>
# </ul>
# <ul class="sub_gnb">
# <li class="">
# <a class="cur_menu mlog" data="LOG_PRT_CODE=1&amp;MENU_PRT_CODE=0&amp;MENU_ID_LV1=&amp;CLICK_AREA_PRT_CODE=S01&amp;ACTION_AF_CLICK=V1" href="javascript:MELON.WEBSVC.POC.menu.goMyMusicMain();"><span class="cur_status none">현재 선택된 메뉴-</span><span class="menu_bg menu09">마이뮤직</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- //header -->
# <div class="clfix" id="cont_wrap">
# <div class="my_fold" id="conts_section">
# <!-- contents -->
# <!-- contents -->
# <div id="conts">
# <div class="page_header">
# <h2 class="title">TOP100</h2> <!-- MELONUIT-1980(24hit > top100) -->
# <div class="tooltip">
# <button class="button_icons etc tooltip" data-control="dropdown" type="button"><span class="none">툴팁보기</span></button>
# <div class="layer_popup" role="dialog">
# <p class="desc">최근 24시간 동안의 이용량과 최근 1시간의 이용량을 반영한 차트이며, 이용량은 스트리밍 40%+다운로드 60%를 기준으로 집계, 매 시간 업데이트 됩니다.<br/>
# 									차트 왜곡을 막기 위해 이용자가 적은 심야와 이른 오전 01시~07시에는 최근 24시간 이용량을 100% 반영한 차트를 발행합니다.<br/>
# 									반영 비율이 달라지는 01시·08시 차트에는 순위 변화를 제공하지 않습니다.
# 								<button class="button_icons etc close d_close" type="button"><span class="none">닫기</span></button>
# </p></div>
# </div>
# </div>
# <div class="multi_row">
# <!-- 시간선택 -->
# <div class="calendar_prid mt12">
# <span class="yyyymmdd">
# <span class="year">2026.09.09</span>
# </span>
# <span class="hhmm">
# <span class="hour">10:00</span>
# </span>
# <div class="time_layer">
# <button class="button_icons etc arrow_d" data-control="dropdown" title="시간선택" type="button">
# <span class="none">시간선택</span>
# </button>
# <div class="l_popup" style="display: none;">
# <div class="box_scroll">
# <ul class="time_list">
# <li><a class="timelist" data-time-value="2026090910" href="#"><span class="time">10:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090909" href="#"><span class="time">09:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090908" href="#"><span class="time">08:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090907" href="#"><span class="time">07:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090906" href="#"><span class="time">06:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090905" href="#"><span class="time">05:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090904" href="#"><span class="time">04:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090903" href="#"><span class="time">03:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090902" href="#"><span class="time">02:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090901" href="#"><span class="time">01:00</span></a></li>
# <li><a class="timelist" data-time-value="2026090900" href="#"><span class="time">00:00</span></a></li>
# </ul>
# </div>
# </div>
# <!-- <span class="rank_update">순위 업데이트!</span> 순위 업데이트 시 dp MELONUIT-1518 삭제 -->
# </div>
# </div>
# <div class="top3 button_group">
# <!-- <button type="button" id="d_tutorial_open"><span class="text">이용안내</span><span class="button_icons etc guide"></span></button> --><!-- // MELONUIT-1518 삭제 -->
# <button id="chart_Refresh" type="button"><span class="text">새로고침</span><span class="button_icons etc refresh"></span></button>
# </div>
# </div>
# <div id="tb_list">
# <form id="frm" name="frm">
# <div class="service_list_song type02 d_song_list">
# <h3 class="none"></h3>
# <!-- 곡리스트 테이블 -->
# <div class="wrap_btn_tb top">
# <button class="button_rbox" onclick="playShuffleChart();" title="셔플듣기" type="button"><span class="button_icons shuffle"></span><span class="cnt">셔플듣기</span></button>
# <button class="button_rbox" onclick="playChart();" title="전체듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">전체듣기</span></button>
# <button class="button_rbox" onclick="melon.play.playFormSong('1000002721','frm');" title="선택된 곡 듣기" type="button"><span class="button_icons type02 play"></span><span class="cnt">듣기</span></button>
# <button class="button_rbox" onclick="melon.play.addFormPlayList('frm');" title="선택된 곡 담기" type="button"><span class="button_icons type02 scrap"></span><span class="cnt">담기</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','0','1000002721');" title="선택된 곡 다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt">다운</span></button>
# <button class="button_rbox" onclick="melon.buy.goBuyProduct('frm','','3C0001','input_check','110','1000002721');" title="선택된 곡 원음다운로드" type="button"><span class="button_icons type02 download"></span><span class="cnt"><span class="eng">FLAC</span></span></button>
# <button class="button_rbox" onclick="melon.buy.goPresent('song', 'frm', '1000002721');" title="선택된 곡 선물하기" type="button"><span class="button_icons type02 gift"></span><span class="cnt">선물</span></button>
# </div>
# <table border="1" style="width:100%">
# <caption>이 표는 곡 리스트로 체크박스, 순위, 곡정보, 좋아요, 뮤비, 다운, 폰전송 내용을 포함하고 있으며 표 상 하단에 제공하는 전체선택, 듣기, 다운로드, 담기, 선물하기 기능을 이용하실 수 있습니다.</caption>
# <colgroup>
# <col style="width: 15px"/><!-- checkbox -->
# <col style="width: 62px"/><!-- 순서 & 순위 -->
# <col style="width: 50px"/><!-- 순위등락 -->
# <col style="width: 60px"/><!-- 앨범이미지 -->
# <col style="width: 24px"/><!-- 곡 상세가기 -->
# <col/><!-- 곡정보 -->
# <col style="width: 190px"/><!-- 앨범 -->
# <col style="width: 111px"/><!-- 좋아요 -->
# <col style="width: 58px"/><!-- 듣기 -->
# <col style="width: 52px"/><!-- 담기 -->
# <col style="width: 52px"/><!-- 다운 -->
# <col style="width: 52px"/><!-- 뮤비 -->
# </colgroup>
# <thead>
# <tr>
# <th scope="col">
# <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
# </th>
# <th scope="col">
# <div class="wrap t_center"><span class="rank">순위</span></div>
# </th>
# <th scope="col">
# <div class="wrap none">순위등락</div>
# </th>
# <th scope="col">
# <div class="wrap none">앨범이미지</div>
# </th>
# <th scope="col">
# <div class="wrap none">곡 상세가기</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">곡정보</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_12">앨범</div>
# </th>
# <th scope="col">
# <div class="wrap pd_l_30">좋아요</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">듣기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">담기</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">다운</div>
# </th>
# <th scope="col">
# <div class="wrap t_center">뮤비</div>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr class="lst50" data-song-no="37928381" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="LOVE ATTACK 곡 선택" type="checkbox" value="37928381"/></div></td>
# <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="/album/detail.htm?albumId=11575849" title="SCENEDROME">
# <img alt="SCENEDROME - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/115/75/849/11575849_20240826152240_500.jpg/melon/resize/120/quality/80/optimize" width="60">
# <span class="bg_album_frame"></span>
# </img></a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="/song/detail.htm?songId=37928381" title="LOVE ATTACK 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',37928381);" title="LOVE ATTACK 재생">LOVE ATTACK</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="/album/detail.htm?albumId=11575849" title="SCENEDROME - 페이지 이동">SCENEDROME</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="37928381" title="LOVE ATTACK 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',37928381);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('37928381');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '37928381', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '37928381','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="602839323" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="BiiiG 곡 선택" type="checkbox" value="602839323"/></div></td>
# <td><div class="wrap t_center"><span class="rank">2</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# <span class="rank_wrap" title="순위 동일">
# <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
# <span class="none">0</span>
# </span>
# </div></td>
# <td><div class="wrap">
# <a class="image_typeAll" href="/album/detail.htm?albumId=14463127" title="BiiiG">
# <img alt="BiiiG - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/144/63/127/14463127_20260819092848_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="/song/detail.htm?songId=602839323" title="BiiiG 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',602839323);" title="BiiiG 재생">BiiiG</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="/artist/detail.htm?artistId=198094" title="BIGBANG (빅뱅) - 페이지 이동">BIGBANG (빅뱅)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=198094" title="BIGBANG (빅뱅) - 페이지 이동">BIGBANG (빅뱅)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="/album/detail.htm?albumId=14463127" title="BiiiG - 페이지 이동">BiiiG</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no
500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
# <span class="bg_album_frame"></span>
# </a>
# </div></td>
# <td><div class="wrap">
# <a class="btn button_icons type03 song_info" href="/song/detail.htm?songId=602322595" title="BAD 곡정보"><span class="none">곡정보</span></a>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank01"><span>
# <a href="javascript:melon.play.playSong('1000002721',602322595);" title="BAD 재생">BAD</a>
# </span></div><br/>
# <div class="ellipsis rank02">
# <a href="/artist/detail.htm?artistId=2398260" title="ATEEZ(에이티즈) - 페이지 이동">ATEEZ(에이티즈)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=2398260" title="ATEEZ(에이티즈) - 페이지 이동">ATEEZ(에이티즈)</a></span>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <div class="wrap_song_info">
# <div class="ellipsis rank03">
# <a href="/album/detail.htm?albumId=13752815" title="GOLDEN HOUR : Part.5 - 페이지 이동">GOLDEN HOUR : Part.5</a>
# </div>
# </div>
# </div></td>
# <td><div class="wrap">
# <button class="button_etc like" data-song-menuid="1000002721" data-song-no="602322595" title="BAD 좋아요" type="button">
# <span class="odd_span">좋아요</span>
# <span class="cnt">
# <span class="none">총건수</span>
# 												0
# 											</span>
# </button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons play" onclick="melon.play.playSong('1000002721',602322595);" title="듣기" type="button"><span class="none">듣기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons scrap" onclick="melon.play.addPlayList('602322595');" title="담기" type="button"><span class="none">담기</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons download" onclick="melon.buy.goBuyProduct('frm', '602322595', '3C0001', '','0', '1000002721');" title="다운로드" type="button"><span class="none">다운로드</span></button>
# </div></td>
# <td><div class="wrap t_center">
# <button class="button_icons video" onclick="melon.link.goMvDetail('1000002721', '602322595','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
# </div></td>
# </tr>
# <tr class="lst50" data-song-no="602115220" id="lst50">
# <td><div class="wrap t_right"><input class="input_check" name="input_check" title="LEMONADE 곡 선택" type="checkbox" value="602115220"/></div></td>
# <td><div class="wrap t_center"><span class="rank">8</span><span class="none">위</span></div></td>
# <!-- 차트순위 추가 -->
# <td><div class="wrap">
# ...
# </div></td>
# </tr>
# </tbody>
# </table>
# </div>
# </form>
# <script type="text/javascript">
# 	$(function(){
#
# 		/* 좋아요 셋팅부 */
# 		var LIKE_SET = {
# 			likeCnt  : "<span class=\"odd_span\">{TXT}</span>\n<span class=\"cnt\">\n<span class=\"none\">총건수</span>\n{CNT}</span>",
# 			likeObj  : $('div.d_song_list button.like'),
# 			likeAttr : 'data-song-no',
# 			likeUrl  : '/commonlike/getSongLike.json'
# 		};
#
# 		/* 좋아요 공통부 */
# 		var contsIdList = LIKE_SET['likeObj'].map(function() { return $(this).attr(LIKE_SET['likeAttr']); }).get().join(',');
# 		var tmpl, title;
# 		if ( contsIdList === '' || contsIdList === null  ) { return; }
# 		$.get(LIKE_SET['likeUrl'], { contsIds : contsIdList }, function(data) {
# 			var robj;
# 			$.each(data.contsLike, function(i, v) {
# 				var SUMMCNT = MELON.WEBSVC.number.addComma(v.SUMMCNT);
# 				robj  = LIKE_SET['likeObj'].eq(i);
# 				tmpl  = LIKE_SET['likeCnt'];
# 				title = robj.attr('title').split(' 좋아요');
# 				robj[v.LIKEYN == 'Y' ? 'addClass' : 'removeClass']('on').attr('title', title[0] + (v.LIKEYN == 'Y' ? ' 좋아요 취소' : ' 좋아요'));
# 				robj.html(
# 					tmpl.replace(/\{TXT\}/g, (v.LIKEYN == 'Y' ? '좋아요 취소' : '좋아요')).replace(/\{CNT\}/g, SUMMCNT)
# 				);
# 			});
# 		}).done(function(){
# 			//아티스트 더보기 처리
# 			var listType = 'CHART';
# 			if(listType == 'CHART'){
# 				WEBELLIPSIS.ellipsis("checkEllipsis","wrap_atist",210);
# 			}else{
# 				WEBELLIPSIS.ellipsis("checkEllipsis","wrap_atist",240);
# 			}
#
# 		});
# 	});
# 	</script>
# <!-- 차트타입 페이징 -->
# <script type="text/javascript">
#
# 				$(function(){
# 					/* 멜론 차트 곡만 듣기 */
# 					playChart = function() {
# 						var songList = $('tr').map(function() { return $(this).attr('data-song-no'); }).get();
# 						melon.play.playSong('1000002721', songList);
# 					}
#
# 					playShuffleChart = function() {
# 						var songList = $('tr').map(function() { return $(this).attr('data-song-no'); }).get();
# 						var j, x, i;
# 						for (i = songList.length; i; i -= 1) {
# 							j = Math.floor(Math.random() * i);
# 							x = songList[i - 1];
# 							songList[i - 1] = songList[j];
# 							songList[j] = x;
# 						}
# 						melon.play.playSong('1000002721', songList);
# 					}
#
# 					/* 리스트 다중 선택 */
# 					$('.input_check').optShift();
# 					/* 페이징 노출*/
# 					$('.chart_page').css({'display':''});
#
# 				});
# 			</script>
# </div>
# </div>
# <!-- //contents -->
# <script type="text/javascript">
# 		var httpWww = "http://www.melon.com";
# 		var httpsWww = "https://www.melon.com";
# 		var POC_ID = "XXXX";
# 		var deployPhase = "";
# 	</script>
# <script src="/resource/script/web/common/melonweb_openlib.js?_resVer=85fc5c88d3e10b8e0cd2bab51e3d426c" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/5t/d/g1chjrrp0qcs.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/0z/4/1dmvbn9lyn.js" type="text/javascript"></script>
# <script src="/resource/script/web/common/MPAPI.js?_resVer=d62c09ec38ce9c0a2d7049a72b222074" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/7x/m/8zbna4xujoeuvm9s.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/6c/7/zlbip87hzvucdld.js" type="text/javascript"></script>
# <!-- commit  -->
# <script src="/resource/script/web/chart/json2.js?_resVer=fd649768dbb10882a2efa370f571a842" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/8k/8/1ed5h822hvv.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/statistics/js/mlog.28ba021f940fcdaa81ff.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara-1.2.0.min.js" type="text/javascript"></script>
# <script src="/resource/script/web/event/bluebird.min.js?_resVer=ec2c84fb362cb1c24e917bbdcf9083a4" type="text/javascript"></script>
# <script src="/resource/script/web/common/melonweb_newtiara.js?_resVer=2168b181aec0097a4ae74988a5e5ad70" type="text/javascript"></script>
# <script src="/resource/script/web/clean/melonweb_clean.js?_resVer=700ea91a5b3de6a68f3cfef4e629b86a" type="text/javascript"></script>
# <script type="text/javascript">
# 		var melon = MELON.WEBSVC.POC;
# 		var menuId = '1000002721';
# 		if(menuId != null && menuId != ''){
# 			tiara.sendLog(menuId);
# 		}
#
# 		document.domain="melon.com";
#
# 		//pocId 쿠키설정 실행
# 		try {
# 			melon.setPocId();
# 		} catch (e){}
# 	</script>
# <script src="/resource/script/web/common/socket.io.js" type="text/javascript"></script>
# <script src="https://static.melon.co.kr/static/web/resource/script/w1/pf/z/14im3r4ty1x.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(function() {
# 		$('#chart_Refresh').click(function() {
# 			moveTime();
# 		});
# 		$('a.timelist').click(function() {
# 			moveTime($(this).attr("data-time-value"));
# 		});
# 		moveTime = function(t) {
# 			var pUrl = "?dayTime=" + t;
# 			if ( typeof t === 'undefined') { pUrl = ""; }
# 			document.location.href = "/chart/index.htm" + pUrl;
# 		}
# 	});
# </script>
# <!-- //contents -->
# </div>
# </div>
# <!-- footer -->
# <div class="my_fold" id="footer">
# <div class="btn_top_wrap">
# <a class="btn_top" href="#skip_nav" style="" title="맨 위로 가기"><span>맨 위로 가기</span></a>
# </div>
# <!-- MELONUIT-738 -->
# <div class="wrap_pop_notice MELONUIT-738" id="popNotice">
# </div>
# <!-- //MELONUIT-738 -->
# <div class="footer_cont">
# <div class="footer_menu">
# <!-- 				<ul class="fl_left"> -->
# <!-- 					<li class="menu01 d_melon_ticket"><a href="http://ticket.melon.com/main/index.htm"><span>MelOn Ticket</span></a></li> -->
# <!-- 					<li class="menu04"><a href="http://aztweb.melon.com/aztalk/guide/web/main.htm"><span>aztalk</span></a></li> -->
# <!-- 				</ul> -->
# <ul class="fl_right">
# <li class="menu10" id="d_studio"><a href="//studio.melon.com/"><span>멜론 스튜디오</span></a></li>
# <li class="menu06"><a href="//www.melon.com/customer/serviceintro/index.htm"><span>Windows 플레이어</span></a></li><!-- 160824 수정 -->
# <li class="menu07"><a href="//www.melon.com/customer/serviceintro/multi_pc_web.htm"><span>Mac 플레이어</span></a></li>
# <li class="menu09"><a href="//www.melon.com/customer/serviceintro/ipad.htm"><span>iPad</span></a></li>
# <li class="menu08"><a href="//faqs2.melon.com/customer/index.htm"><span>고객센터</span></a></li>
# </ul>
# </div>
# <ul class="footer_policy clfix">
# <li class="first_child"><a href="//info.melon.com/terms/web/terms1_1.html" target="_blank" title="이용약관 ">이용약관</a></li>
# <li><a href="//info.melon.com/terms/web/terms1_3.html" target="_blank" title="위치기반서비스 이용약관 "><strong>위치기반서비스 이용약관</strong></a></li>
# <li><a href="//info.melon.com/terms/web/terms3.html" target="_blank" title="개인정보처리방침 "><strong>개인정보처리방침</strong></a></li>
# <li><a href="//info.melon.com/terms/web/terms5_1.html" target="_blank" title="청소년보호정책">청소년보호정책</a></li>
# <li><a href="//faqs2.melon.com/customer/faq/informFaq.htm?no=1&amp;faqId=QUES20140616000001&amp;SEARCH_KEY=&amp;SEARCH_PAR_CATEGORY=CATE20130909000006&amp;SEARCH_CATEGORY=CATE20130909000021" title="제휴/프로모션문의">제휴/프로모션문의</a></li>
# <li><a href="javascript:openEmailCollectionReject();" title="이메일주소무단수집거부 ">이메일주소무단수집거부</a></li>
# <li class="last_child"><a href="//partner.melon.com/partrct/login/web/login_loginProcess.htm?t=s" target="_blank" title="파트너센터">파트너센터</a></li>
# </ul>
# <!--160531 수정 lyr-->
# <p>
# <span class="first"><strong>(주)카카오엔터테인먼트</strong>  경기도 성남시 분당구 판교역로 235, 에이치스퀘어 N동 8, 9, 10층</span>
# <span>공동대표이사 : 고정희, 장윤중</span>
# <span>사업자등록번호 : 220-88-02594</span>
# <span>통신판매업신고번호 : 2018-성남분당B-0004 <a class="btn_arrow" href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=2208802594" target="_blank" title="사업자정보확인">사업자정보확인</a></span>
# <br>
# <span class="first">문의전화 : 1566-7727 (평일 09:00-18:00, 유료)</span>
# <span>이메일 : <a class="btn_footer_mail" href="mailto:melon_info@kakaoent.com">melon_info@kakaoent.com</a></span>
# <span>호스팅서비스사업자 : (주)카카오엔터테인먼트</span>
# <span><a class="btn_footer_mail" href="//kakaoent.com" target="_blank">© Kakao Entertainment Corp.</a></span>
# </br></p>
# <!--//160531 수정 lyr-->
# <!--모바일 웹 버전, 태블릿에서만 적용됨. display none, block 으로 적용-->
# <!--140602 추가 lyr-->
# <div class="mobile_btn_wrap" style="display:none;">
# <p>접속하신 단말/브라우저에서는 멜론 서비스의 사용이 일부 제한될 수 있습니다. 양해부탁드립니다.</p>
# <a class="btn" href="#" title="모바일 웹 버전">
# <span class="odd_span">
# <span class="even_span">모바일 웹 버전</span>
# </span>
# </a>
# </div>
# <!--//140602 추가 lyr-->
# </div>
# <a class="btn_top" href="#" style="display: none;" title="맨 위로 가기">맨 위로 가기</a>
# <!-- MELONUIT-1148 20200121 ISMS 인증서 팝업 -->
# <div class="wrap_pop_notice wrap_pop_isms" id="pop_isms">
# <div class="pop_isms_inner">
# <h1 class="title">정보보호 및 개인정보보호 관리체계 인증</h1>
# <div class="cntt">
# <p class="txt01">정보보호 및 개인정보보호를 위한 일련의 조치와 활동이<br>인증기준에 적합함을 인터넷진흥원 또는 인증기간이 증명하는 제도</br></p>
# <ul class="list_isms">
# <li>[인증범위]  인터넷 서비스 운영 (카카오, 다음, 멜론)</li>
# <li>[유효기간]  2019.12.26 ~ 2022.12.25</li>
# </ul>
# </div>
# </div>
# <button class="btn_close d_close" title="닫기" type="button"><span>닫기</span></button>
# <span class="shadow"></span>
# </div>
# <!-- //MELONUIT-1148 20200121 ISMS 인증서 팝업 -->
# <script type="text/javascript">
# 			$(function() {
# 				//favicon 분기 처리
# 				var pocId = MELON.WEBSVC.POC.getPocId();
# 				if('AS20' == pocId || 'HT10' == pocId){
# 					$('link#favicon').attr('href','//cdnimg.melon.co.kr/resource/mobile40/cds/common/image/favicon.ico');
# 					$('title').text('Melon');
# 				}else if('IS20' == pocId || 'IT10' == pocId){
# 					$('link#favicon').attr('type','');
# 					$('link#favicon').attr('rel','apple-touch-icon-precomposed');
# 					$('link#favicon').attr('href','//cdnimg.melon.co.kr/resource/mobile40/cds/common/image/mobile_apple_120x120.png');
# 					$('link#favicon').after('<link rel="apple-touch-icon-precomposed" sizes="180x180" href="//cdnimg.melon.co.kr/resource/mobile40/cds/common/image/mobile_apple_180x180.png" />');
# 					$('title').text('Melon');
# 				}
#
# 				// 엣지 브라우저이고 해당 팝업이 뜬 적이 없는 경우 체크하여 팝업을 띄운다.
# 				var isEdge = (navigator.userAgent.indexOf("Edge") > 0);
# 				var edgeCheckYN = getCookie("EDGE_CHECK") != 'Y';
#
#
# 				// 타블렛이고 해당 팝업이 뜬 적이 없는 경우 체크하여 팝업을 띄운다.
# 				var tabletCheckYN = getCookie("TABLET_CHECK") != 'Y';
#
# 				if(melon.isTablet() && tabletCheckYN){
# 					window.open('//www.melon.com/error_page/error_tabletTypeA.html','tabletPopTypeA','scrollbars=no, resizable=no, location=no, width=560, height=483');
# 				}
#
# 				// 해당 쿠키가 존재하면 쿠키 삭제
# 				if(getCookie("CHECK_POP") != ''){
# 					// 체크 후 해당 쿠키는 제거
# 					var expireDate = new Date();
# 					expireDate.setDate(expireDate.getDate()-1);
# 					document.cookie = "CHECK_POP=;path=/;expires="+expireDate.toGMTString()+";domain=.melon.com";
# 				}
#
# 				if(isMelonLogin()){
# 					var djYn = false;
# 					var memberKey = getMemberKey();
#
#
# 					if(memberKey != null || memberKey != ''){
# 						var url = '/dj/members/'+memberKey+'/isdj.json';
# 						var promotionPopup = window.localStorage.getItem('promotionpopup'+getMemberKey());
#
# 						try {
# 							$.ajax({
# 								url: url,
# 								type : 'GET',
# 								dataType: 'json'
# 							}).done(function(data) {
# 								if (data != null && data.ISDJ != null && data.ISDJ.length > 0) {
# 									djYn = data.ISDJ;
# 								}
# 							}).fail(function() {
# 								djYn = false;
# 							});
#
#
# 							if(promotionPopup == null && isLoginWithin20Seconds()){
# 								var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
#
# 								// PCP이면 찌르지 않음
# 								if(POC_ID != 'VP40' && fromMPS.indexOf("MELONPLAYER") < 0) {
# 									$.ajax({
# 										url: '/commapi/v1/loginPromotion.json',
# 										type : 'GET',
# 										dataType: 'json',
# 										data : {memberKey : memberKey,
# 											pocId : getCookie("POC")}
# 									}).done(function(data) {
# 										if (data != undefined && data != null && data.PROMOTIONINFO != null && data.PROMOTIONINFO.PROMOTARGETMAP != null) {
# 											if(data.PROMOTIONINFO.PROMOTARGETMAP.promoLinkUrl != null){
# 												var promotionLinkUrl = data.PROMOTIONINFO.PROMOTARGETMAP.promoLinkUrl;
#
# 												try {
# 													var urlObj = new URL(promotionLinkUrl);
# 													var params = new URLSearchParams(urlObj.search);
# 												} catch (e) {
# 													var params = new URLSearchParams();
# 												}
#
# 												var width = params.get("width")  != null ? params.get("width") : '560';
# 												var height = params.get("height") != null ? params.get("height") : '780';
# 												var inflowCode = params.get("inflowCode") != null ? params.get("inflowCode") : '';
# 												var loginPromoId = params.get("loginPromoId") != null ? params.get("loginPromoId") : '';
#
# 												//inflowCode값이 IC0017가 아니거나, 해당 쿠키값이 존재하지 않을 떄 팝업 호출
# 												if (inflowCode != "IC0017" || getCookie('block_'+getMemberKey()+'_'+loginPromoId) == '') {
# 													window.open(promotionLinkUrl, '', 'width='+width+', height='+height+', left=50, top=100');
# 												}
#
# 												window.localStorage.setItem('promotionpopup'+getMemberKey(), '1');
# 											}
# 										}
# 									}).fail(function() {
# 										console.log('promotionPopup AJAX Failed!!!');
# 										window.localStorage.removeItem('promotionpopup'+getMemberKey());
# 									});
# 								}
# 							}
#
# 						} catch(e){}
# 					}
# 				}
#
# 				// 홈탭의 경우 쇼핑/티켓을 새창띄우기로 변경한다.
# 				var fromMPS = getCookie("MPS"); // 멜론 플레이어에서 왔는지 확인.
# 				var fromHomeTab = !(fromMPS == null || fromMPS.indexOf("MELONPLAYER") < 0);
#
# 				if(fromHomeTab){
# 					$("li.d_melon_shopping a").removeClass("mlog");
# 					$("li.d_melon_shopping a").addClass("mlog_without_page_change");
# 					$("li.d_melon_shopping a").attr("target", "_blank");
#
# 					$("li.d_melon_ticket a").removeClass("mlog");
# 					$("li.d_melon_ticket a").addClass("mlog_without_page_change");
# 					$("li.d_melon_ticket a").attr("target", "_blank");
# 				}
#
# 				//멜론 플레이어면 멜론 6.0 둘러보기 버튼 제거
# 				if(fromHomeTab){
# 					$('#d_studio').hide()
# 					$('#d_melon6').hide();
# 				}else{
# 					$('#d_studio').show()
# 					$('#d_melon6').show();
# 				}
#
# 				$(document).on('limitpopup', function( e, cookieId ) {
# 					$('#'+cookieId).modal();
# 				});
#
#
# 				//레이어 공지 제어
# 				//메인만 적용
# 				//pcp 홈탭 미적용
# 				if('10010101' == '1000002721' && !fromHomeTab){
# 					$.ajax({
# 						type : 'GET'
# 						,url : '/main/getTicketPositionProperty.json'
# 					}).done(function(response) {
#
# 						var layerPopNotiYn = response.layerPopNotiYn;
# 						var layerPopDateText = response.layerPopDateText;
# 						if(layerPopNotiYn == 'Y'){
# 							$('#d_layerPopDateText').text(layerPopDateText);
# 							setTimeout(function() {
# 								$("#popNotice").timeLimitSet({ cookieId:'popNotice',selectors:{closebtn:'#todayChk', checkbox:''} });
# 							},1);
# 							MELON.PBPGN.TimeLimitPopup.init({ cookieId:"popNotice", serverTime: new Date(), limitType:"day" });
# 							$("#popNotice .d_close").click(function() {  $("#popNotice").modal('hide'); });
# 						}
# 					});
# 				}
# 			});
#
# 			function goMelonTPage(){
# 				//t.com 종료 삭제처리
# 			}
#
# 			function isLoginWithin20Seconds() {
# 				const now = new Date();
# 				const loginTime = parseLoginTime(getLoginTime());
# 				const timeDifference = Math.abs(now - loginTime) / 1000;
# 				return timeDifference <= 20;
# 			}
#
# 			function parseLoginTime(loginTimeStr) {
# 				const year = parseInt(loginTimeStr.substring(0, 4), 10);
# 				const month = parseInt(loginTimeStr.substring(4, 6), 10) - 1;
# 				const day = parseInt(loginTimeStr.substring(6, 8), 10);
# 				const hours = parseInt(loginTimeStr.substring(8, 10), 10);
# 				const minutes = parseInt(loginTimeStr.substring(10, 12), 10);
# 				const seconds = parseInt(loginTimeStr.substring(12, 14), 10);
#
# 				return new Date(year, month, day, hours, minutes, seconds);
# 			}
#
# 			function openEmailCollectionReject(){
# 				window.open('//www.melon.com/emailCollectionReject.html','emailCollect', 'scrollbars=no, resizable=no, location=no, width=384, height=331');
# 			}
#
# 			//MELONUIT-1148 20200121 ISMS 인증서 팝업 //
# 			var popISMS = {
# 				open : function() {
# 					$('#pop_isms').modal('show');
# 				}
# 			};
#
# 			$(document).on('click', '.popISMS',function(){
# 				popISMS.open();
# 			});
# 			//MELONUIT-1148 20200121 ISMS 인증서 팝업 //
# 		</script>
# <!--//140602 추가 lyr-->
# </div>
# <!-- //footer -->
# </div>
# </body>
# </html>

# %%
# melon_soup.select("a")

# %%
song_info_wrap = melon_soup.select(".wrap_song_info")
song_info_wrap
# Out:
# [<div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',37928381);" title="LOVE ATTACK 재생">LOVE ATTACK</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=11575849" title="SCENEDROME - 페이지 이동">SCENEDROME</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',602839323);" title="BiiiG 재생">BiiiG</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=198094" title="BIGBANG (빅뱅) - 페이지 이동">BIGBANG (빅뱅)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=198094" title="BIGBANG (빅뱅) - 페이지 이동">BIGBANG (빅뱅)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=14463127" title="BiiiG - 페이지 이동">BiiiG</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',602024048);" title="갑자기 재생">갑자기</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=960251" title="아이오아이 (I.O.I) - 페이지 이동">아이오아이 (I.O.I)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=960251" title="아이오아이 (I.O.I) - 페이지 이동">아이오아이 (I.O.I)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=13399673" title="I.O.I 3rd MINI ALBUM [I.O.I : LOOP] - 페이지 이동">I.O.I 3rd MINI ALBUM [I.O.I : LOOP]</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',601807965);" title="REDRED 재생">REDRED</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=4491260" title="CORTIS (코르티스) - 페이지 이동">CORTIS (코르티스)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=4491260" title="CORTIS (코르티스) - 페이지 이동">CORTIS (코르티스)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=13338387" title="GREENGREEN - 페이지 이동">GREENGREEN</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',602450078);" title="Pretty Girl 재생">Pretty Girl</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=13788545" title="Pretty Girl - Special Single - 페이지 이동">Pretty Girl - Special Single</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',39231685);" title="Deja Vu 재생">Deja Vu</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=3709231" title="RESCENE (리센느) - 페이지 이동">RESCENE (리센느)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=11875116" title="Dearest - 페이지 이동">Dearest</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',602322595);" title="BAD 재생">BAD</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=2398260" title="ATEEZ(에이티즈) - 페이지 이동">ATEEZ(에이티즈)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=2398260" title="ATEEZ(에이티즈) - 페이지 이동">ATEEZ(에이티즈)</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=13752815" title="GOLDEN HOUR : Part.5 - 페이지 이동">GOLDEN HOUR : Part.5</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',602115220);" title="LEMONADE 재생">LEMONADE</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=2899555" title="aespa - 페이지 이동">aespa</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId=2899555" title="aespa - 페이지 이동">aespa</a></span>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="/album/detail.htm?albumId=13384085" title="LEMONADE - The 2nd Album - 페이지 이동">LEMONADE - The 2nd Album</a>
#  </div>
#  </div>,
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('1000002721',602377105);" title="만찬가 재생">만찬가</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="/artist/detail.htm?artistId=236797" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a><span class="checkEllipsis" style="display:none"><a href="/artist/detail.htm?artistId
'어떻게 이별까지 사랑하겠어, 널 사랑하는 거지', '404 (New Era)', '너의 모든 순간', '어제보다 슬픈 오늘', 'BANG BANG', '그댈 위한 멜로디', '한 페이지가 될 수 있게', '내게 사랑이 뭐냐고 물어본다면', '너에게 닿기를', 'Blue Valentine', '모르시나요(PROD.로코베리)', '뛰어(JUMP)', 'Less than a Lover', '천상연', '멸종위기사랑', '소나기', 'toxic till the end', 'Guitarist', '봄 내음보다 너를', 'Heavy Serenade', 'HAPPY', '그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))', 'SWIM', 'Whiplash', 'Golden', '모든 날, 모든 순간 (Every day, Every Moment)', 'like JENNIE', 'Runaway', '청춘만화', '나는야 HERO', '주저하는 연인들을 위해', '이 밤을 빌려 말해요', "Surfin' Boy", '그대 작은 나의 세상이 되어', 'Seven (feat. Latto) - Clean Ver.', '입춘', '나는 반딧불', 'Dynamite', 'Vitamin ME', '봄날', '사랑인가 봐', '예뻤어', '첫 만남은 계획대로 되지 않아', 'APT.', 'Die With A Smile', '청혼하지 않을 이유를 못 찾았어', 'Hype Boy', 'Love Love Love (Feat. Yoong Jin Of Casker)', '다정히 내 이름을 부르면', '사랑은 봄비처럼...이별은 겨울비처럼...', '헤어지자 말해요', 'Body to Body', 'Welcome to the Show', 'Love wins all', '하루 하루', 'STYLE', '오늘만 I LOVE YOU', 'Magnetic', 'REBEL HEART', '시작의 아이 ❍']

# %%
singers = melon_soup.select(".wrap_song_info > .rank02 > span")

singer_list = list(map(lambda tag: tag.text.replace("\xa0", " "), singers))
# singer_list

# %%
# like_list에 멜론에 좋아요 수들을 순서대로 담고 리스트로 가져오기

likes_url = "https://www.melon.com/commonlike/getSongLike.json?contsIds=37928381%2C602839323%2C602024048%2C601807965%2C602450078%2C39231685%2C602322595%2C602115220%2C602377105%2C602951446%2C601899271%2C34061322%2C36397952%2C602939768%2C602552833%2C36730261%2C600287375%2C601479669%2C602951447%2C601332163%2C39765727%2C602951444%2C39504779%2C602951445%2C34908740%2C602732384%2C601719416%2C602951448%2C38242510%2C602940179%2C36985781%2C601719413%2C602951449%2C602951452%2C602951450%2C602951451%2C602313594%2C602951453%2C600299706%2C37473973%2C32061975%2C4446485%2C601013499%2C38733032%2C601237102%2C31927275%2C38104031%2C600243411%2C38429074%2C38626852%2C39765731%2C39298775%2C37228861%2C39307948%2C37390939%2C602584682%2C38300904%2C601879407%2C601555642%2C37323944%2C36699489%2C38123332%2C33411344%2C39166708%2C38071559%2C30962526%2C38629386%2C601719493%2C600791038%2C36617841%2C31666417%2C33241003%2C602683997%2C603019497%2C32872978%2C39765734%2C38123338%2C30244931%2C34657844%2C34753369%2C602540014%2C30232719%2C37140709%2C36382580%2C38120327%2C37375706%2C35454426%2C37901626%2C33496587%2C1556553%2C37347911%2C37145732%2C37323943%2C601555636%2C38444825%2C39161085%2C38426197%2C1121123%2C39566906%2C38635449"
response = requests.get(likes_url, headers=headers)
# like(map(lambda like_data: like_data["SUMMCNT"], json.loads(response.text)["contsLike"]))

like_list = [i["SUMMCNT"] for i in json.loads(response.text)["contsLike"]]
like_list
# Out:
# [145712,
#  53283,
#  77708,
#  88063,
#  60519,
#  51383,
#  28176,
#  57665,
#  44528,
#  20971,
#  58180,
#  239513,
#  308104,
#  22393,
#  25970,
#  148063,
#  124743,
#  50443,
#  18190,
#  74268,
#  52086,
#  18619,
#  123795,
#  17986,
#  127151,
#  19327,
#  91995,
#  17094,
#  233354,
#  10558,
#  46178,
#  89938,
#  16723,
#  17185,
#  16580,
#  16616,
#  32148,
#  16804,
#  78686,
#  92707,
#  496507,
#  326129,
#  72469,
#  90336,
#  68554,
#  371181,
#  102088,
#  121053,
#  110611,
#  155880,
#  41093,
#  99743,
#  150051,
#  105754,
#  201260,
#  25416,
#  161147,
#  55107,
#  64209,
#  218372,
#  178339,
#  156053,
#  140641,
#  193488,
#  106800,
#  433659,
#  113143,
#  32555,
#  34060,
#  233555,
#  453954,
#  88173,
#  21498,
#  6594,
#  461114,
#  35745,
#  160465,
#  501977,
#  239651,
#  83238,
#  18226,
#  381570,
#  177020,
#  195982,
#  222343,
#  77288,
#  317891,
#  141139,
#  225638,
#  128850,
#  148874,
#  225806,
#  202718,
#  48910,
#  122505,
#  65966,
#  190061,
#  75498,
#  74538,
#  90966]

# %%
# 파이썬에서 이미지를 리사이징하거나 보여주는 모듈
from PIL import Image
from urllib.request import urlopen

images = [img_tag["src"] for img_tag in melon_soup.select(".image_typeAll img")]

# for url in images:
    # Image.open(urlopen(url)).resize((100, 100)).show()

# %%
singers = melon_soup.select(".wrap_song_info > .rank02 > span")

for i in singers:
    print(i.text)

# singer_list = list(map(lambda tag: tag.text.replace("\xa0", " "), singers))
# singer_list
# Out:
# RESCENE (리센느)
# BIGBANG (빅뱅)
# 아이오아이 (I.O.I)
# CORTIS (코르티스)
# RESCENE (리센느)
# RESCENE (리센느)
# ATEEZ(에이티즈)
# aespa
# 태연 (TAEYEON)
# BIG Naughty (서동현)
# 임영웅
# 아일릿(ILLIT)
# WOODZ
# 임영웅
# 볼빨간사춘기
# 한로로
# 임영웅
# 임영웅
# 소녀시대-효리수 (Girls' Generation-HRS)
# 임영웅
# 임영웅
# KiiiKiii (키키)
# YENA (최예나)
# 화사 (HWASA)
# Hearts2Hearts (하츠투하츠)
# 임영웅
# 임영웅
# 임영웅
# 한로로
# 임영웅
# 임영웅
# 임영웅
# 최유리
# 임영웅
# G-DRAGON
# AKMU (악뮤)
# AKMU (악뮤)
# Hearts2Hearts (하츠투하츠)
# 다비치
# 도경수(D.O.)
# AKMU (악뮤)
# KiiiKiii (키키)
# 성시경
# 우디 (Woody)
# IVE (아이브)
# 임영웅
# DAY6 (데이식스)
# 로이킴
# 10CM
# NMIXX
# 조째즈
# BLACKPINK
# 제니 (JENNIE)
# 이창섭
# 이찬혁
# 이클립스 (ECLIPSE)
# 로제 (ROSÉ)
# 도경수(D.O.)
# 김나영
# NMIXX
# DAY6 (데이식스)
# 너드커넥션 (Nerd Connection)
# 방탄소년단
# aespa
# HUNTR/X, EJAE, AUDREY NUNA, REI AMI, KPop Demon Hunters Cast
# 폴킴
# 제니 (JENNIE)
# RESCENE (리센느)
# 이무진
# 임영웅
# 잔나비
# PLAVE
# Red Velvet (레드벨벳)
# 카더가든
# 정국
# 한로로
# 황가람
# 방탄소년단
# 프로미스나인
# 방탄소년단
# 멜로망스
# DAY6 (데이식스)
# TWS (투어스)
# 로제 (ROSÉ), Bruno Mars
# Lady Gaga, Bruno Mars
# 이무진
# NewJeans
# 에픽하이 (EPIK HIGH)
# 경서예지, 전건호
# 임현정
# 박재정
# 방탄소년단
# DAY6 (데이식스)
# 아이유
# BIGBANG (빅뱅)
# Hearts2Hearts (하츠투하츠)
# BOYNEXTDOOR
# 아일릿(ILLIT)
# IVE (아이브)
# 박다혜, 마크툽 (MAKTUB)

# %%
print(len(images), len(singers), len(titles), len(like_list))
# Out:
# 100 100 100 100

# %%
rank_list = [str(i) + "위" for i in range(1, 101)]

melon_rank = list(zip(rank_list, title_list, singer_list, images, like_list))
melon_rank
# Out:
# [('1위',
#   'LOVE ATTACK',
#   'RESCENE (리센느)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/115/75/849/11575849_20240826152240_500.jpg/melon/resize/120/quality/80/optimize',
#   145712),
#  ('2위',
#   'BiiiG',
#   'BIGBANG (빅뱅)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/144/63/127/14463127_20260819092848_500.jpg/melon/resize/120/quality/80/optimize',
#   53283),
#  ('3위',
#   '갑자기',
#   '아이오아이 (I.O.I)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/133/99/673/13399673_20260518151131_500.jpg/melon/resize/120/quality/80/optimize',
#   77708),
#  ('4위',
#   'REDRED',
#   'CORTIS (코르티스)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/133/38/387/13338387_20260504133459_500.jpg/melon/resize/120/quality/80/optimize',
#   88063),
#  ('5위',
#   'Pretty Girl',
#   'RESCENE (리센느)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/137/88/545/13788545_20260707111659_500.jpg/melon/resize/120/quality/80/optimize',
#   60519),
#  ('6위',
#   'Deja Vu',
#   'RESCENE (리센느)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/118/75/116/11875116_20250701165641_500.jpg/melon/resize/120/quality/80/optimize',
#   51383),
#  ('7위',
#   'BAD',
#   'ATEEZ(에이티즈)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/137/52/815/13752815_20260622141535_500.jpg/melon/resize/120/quality/80/optimize',
#   28176),
#  ('8위',
#   'LEMONADE',
#   'aespa',
#   'https://cdnimg.melon.co.kr/cm2/album/images/133/84/085/13384085_20260528181046_500.jpg/melon/resize/120/quality/80/optimize',
#   57665),
#  ('9위',
#   '만찬가',
#   '태연 (TAEYEON)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/137/65/551/13765551_20260626112146_500.jpg/melon/resize/120/quality/80/optimize',
#   44528),
#  ('10위',
#   '노스탈지아',
#   'BIG Naughty (서동현)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/144/94/275/14494275_20260828144050_500.jpg/melon/resize/120/quality/80/optimize',
#   20971),
#  ('11위',
#   '또또',
#   '임영웅',
#   'https://cdnimg.melon.co.kr/cm2/album/images/144/98/154/14498154_20260831161140_500.jpg/melon/resize/120/quality/80/optimize',
#   58180),
#  ('12위',
#   'It′s Me',
#   '아일릿(ILLIT)',
#   'https://cdnimg.melon.co.kr/cm2/album/images
#   'NMIXX',
#   'https://cdnimg.melon.co.kr/cm2/album/images/121/49/391/12149391_20251013150421_500.jpg/melon/resize/120/quality/80/optimize',
#   155880),
#  ('51위',
#   '모르시나요(PROD.로코베리)',
#   '조째즈',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/85/729/11685729_20250106160640_500.jpg/melon/resize/120/quality/80/optimize',
#   41093),
#  ('52위',
#   '뛰어(JUMP)',
#   'BLACKPINK',
#   'https://cdnimg.melon.co.kr/cm2/album/images/118/90/480/11890480_20250711095238_500.jpg/melon/resize/120/quality/80/optimize',
#   99743),
#  ('53위',
#   'Less than a Lover',
#   '제니 (JENNIE)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/139/67/276/13967276_20260723112744_500.jpg/melon/resize/120/quality/80/optimize',
#   150051),
#  ('54위',
#   '천상연',
#   '이창섭',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/21/941/11421941_20240220105008_500.jpg/melon/resize/120/quality/80/optimize',
#   105754),
#  ('55위',
#   '멸종위기사랑',
#   '이찬혁',
#   'https://cdnimg.melon.co.kr/cm2/album/images/118/91/198/11891198_20250714145747_500.jpg/melon/resize/120/quality/80/optimize',
#   201260),
#  ('56위',
#   '소나기',
#   '이클립스 (ECLIPSE)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/59/325/11459325_20240405171054_500.jpg/melon/resize/120/quality/80/optimize',
#   25416),
#  ('57위',
#   'toxic till the end',
#   '로제 (ROSÉ)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/59/696/11659696_20241205141243_500.jpg/melon/resize/120/quality/80/optimize',
#   161147),
#  ('58위',
#   'Guitarist',
#   '도경수(D.O.)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/145/26/395/14526395_20260907104149_500.jpg/melon/resize/120/quality/80/optimize',
#   55107),
#  ('59위',
#   '봄 내음보다 너를',
#   '김나영',
#   'https://cdnimg.melon.co.kr/cm2/album/images/105/92/109/10592109_20210413181735_500.jpg/melon/resize/120/quality/80/optimize',
#   64209),
#  ('60위',
#   'Heavy Serenade',
#   'NMIXX',
#   'https://cdnimg.melon.co.kr/cm2/album/images/133/57/541/13357541_20260511133217_500.jpg/melon/resize/120/quality/80/optimize',
#   218372),
#  ('61위',
#   'HAPPY',
#   'DAY6 (데이식스)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/44/397/11444397_20240318115810_500.jpg/melon/resize/120/quality/80/optimize',
#   178339),
#  ('62위',
#   '그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))',
#   '너드커넥션 (Nerd Connection)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/113/05/759/11305759_20230814111006_500.jpg/melon/resize/120/quality/80/optimize',
#   156053),
#  ('63위',
#   'SWIM',
#   '방탄소년단',
#   'https://cdnimg.melon.co.kr/cm2/album/images/129/27/820/12927820_20260320091310_500.jpg/melon/resize/120/quality/80/optimize',
#   140641),
#  ('64위',
#   'Whiplash',
#   'aespa',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/20/540/11620540_20241018183208_500.jpg/melon/resize/120/quality/80/optimize',
#   193488),
#  ('65위',
#   'Golden',
#   'HUNTR/X, EJAE, AUDREY NUNA, REI AMI, KPop Demon Hunters Cast',
#   'https://cdnimg.melon.co.kr/cm2/album/images/118/59/863/11859863_20250620104512_500.jpg/melon/resize/120/quality/80/optimize',
#   106800),
#  ('66위',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   '폴킴',
#   'https://cdnimg.melon.co.kr/cm/album/images/101/49/492/10149492_500.jpg/melon/resize/120/quality/80/optimize',
#   433659),
#  ('67위',
#   'like JENNIE',
#   '제니 (JENNIE)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/117/30/946/11730946_20250307173452_500.jpg/melon/resize/120/quality/80/optimize',
#   113143),
#  ('68위',
#   'Runaway',
#   'RESCENE (리센느)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/133/12/413/13312413_20260406143448_500.jpg/melon/resize/120/quality/80/optimize',
#   32555),
#  ('69위',
#   '청춘만화',
#   '이무진',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/08/521/11608521_20241004161722_500.jpg/melon/resize/120/quality/80/optimize',
#   34060),
#  ('70위',
#   '나는야 HERO',
#   '임영웅',
#   'https://cdnimg.melon.co.kr/cm2/album/images/120/83/192/12083192_20250828155052_500.jpg/melon/resize/120/quality/80/optimize',
#   233555),
#  ('71위',
#   '주저하는 연인들을 위해',
#   '잔나비',
#   'https://cdnimg.melon.co.kr/cm/album/images/102/60/858/10260858_500.jpg/melon/resize/120/quality/80/optimize',
#   453954),
#  ('72위',
#   '이 밤을 빌려 말해요',
#   'PLAVE',
#   'https://cdnimg.melon.co.kr/cm2/album/images/124/58/320/12458320_20251226151630_500.jpg/melon/resize/120/quality/80/optimize',
#   88173),
#  ('73위',
#   "Surfin' Boy",
#   'Red Velvet (레드벨벳)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/143/29/378/14329378_20260731120101_500.jpg/melon/resize/120/quality/80/optimize',
#   21498),
#  ('74위',
#   '그대 작은 나의 세상이 되어',
#   '카더가든',
#   'https://cdnimg.melon.co.kr/cm2/album/images/105/54/647/10554647_20210127173809_500.jpg/melon/resize/120/quality/80/optimize',
#   6594),
#  ('75위',
#   'Seven (feat. Latto) - Clean Ver.',
#   '정국',
#   'https://cdnimg.melon.co.kr/cm2/album/images/112/86/070/11286070_20230713181059_500.jpg/melon/resize/120/quality/80/optimize',
#   461114),
#  ('76위',
#   '입춘',
#   '한로로',
#   'https://cdnimg.melon.co.kr/cm2/album/images/108/90/163/10890163_20220311160155_500.jpg/melon/resize/120/quality/80/optimize',
#   35745),
#  ('77위',
#   '나는 반딧불',
#   '황가람',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/20/541/11620541_20241018183253_500.jpg/melon/resize/120/quality/80/optimize',
#   160465),
#  ('78위',
#   'Dynamite',
#   '방탄소년단',
#   'https://cdnimg.melon.co.kr/cm2/album/images/104/79/150/10479150_20200918102847_500.jpg/melon/resize/120/quality/80/optimize',
#   501977),
#  ('79위',
#   'Vitamin ME',
#   '프로미스나인',
#   'https://cdnimg.melon.co.kr/cm2/album/images/138/16/948/13816948_20260720140607_500.jpg/melon/resize/120/quality/80/optimize',
#   239651),
#  ('80위',
#   '봄날',
#   '방탄소년단',
#   'https://cdnimg.melon.co.kr/cm/album/images/100/37/969/10037969_500.jpg/melon/resize/120/quality/80/optimize',
#   83238),
#  ('81위',
#   '사랑인가 봐',
#   '멜로망스',
#   'https://cdnimg.melon.co.kr/cm2/album/images/108/71/162/10871162_20220217162422_500.jpg/melon/resize/120/quality/80/optimize',
#   18226),
#  ('82위',
#   '예뻤어',
#   'DAY6 (데이식스)',
#   'https://cdnimg.melon.co.kr/cm/album/images/100/36/099/10036099_500.jpg/melon/resize/120/quality/80/optimize',
#   381570),
#  ('83위',
#   '첫 만남은 계획대로 되지 않아',
#   'TWS (투어스)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/113/91/902/11391902_20250922111638_500.jpg/melon/resize/120/quality/80/optimize',
#   177020),
#  ('84위',
#   'APT.',
#   '로제 (ROSÉ), Bruno Mars',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/19/809/11619809_20241018103507_500.jpg/melon/resize/120/quality/80/optimize',
#   195982),
#  ('85위',
#   'Die With A Smile',
#   'Lady Gaga, Bruno Mars',
#   'https://cdnimg.melon.co.kr/cm2/album/images/115/68/901/11568901_20240816130602_500.jpg/melon/resize/120/quality/80/optimize',
#   222343),
#  ('86위',
#   '청혼하지 않을 이유를 못 찾았어',
#   '이무진',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/55/285/11455285_20240401151801_500.jpg/melon/resize/120/quality/80/optimize',
#   77288),
#  ('87위',
#   'Hype Boy',
#   'NewJeans',
#   'https://cdnimg.melon.co.kr/cm2/album/images/110/11/565/11011565_20220801102637_500.jpg/melon/resize/120/quality/80/optimize',
#   317891),
#  ('88위',
#   'Love Love Love (Feat. Yoong Jin Of Casker)',
#   '에픽하이 (EPIK HIGH)',
#   'https://cdnimg.melon.co.kr/cm/album/images/003/42/967/342967_500.jpg/melon/resize/120/quality/80/optimize',
#   141139),
#  ('89위',
#   '다정히 내 이름을 부르면',
#   '경서예지, 전건호',
#   'https://cdnimg.melon.co.kr/cm2/album/images/106/10/525/10610525_20210518143433_500.jpg/melon/resize/120/quality/80/optimize',
#   225638),
#  ('90위',
#   '사랑은 봄비처럼...이별은 겨울비처럼...',
#   '임현정',
#   'https://cdnimg.melon.co.kr/cm/album/images/003/14/795/314795_500.jpg/melon/resize/120/quality/80/optimize',
#   128850),
#  ('91위',
#   '헤어지자 말해요',
#   '박재정',
#   'https://cdnimg.melon.co.kr/cm2/album/images/112/27/533/11227533_20230419162238_500.jpg/melon/resize/120/quality/80/optimize',
#   148874),
#  ('92위',
#   'Body to Body',
#   '방탄소년단',
#   'https://cdnimg.melon.co.kr/cm2/album/images/129/27/820/12927820_20260320091310_500.jpg/melon/resize/120/quality/80/optimize',
#   225806),
#  ('93위',
#   'Welcome to the Show',
#   'DAY6 (데이식스)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/44/397/11444397_20240318115810_500.jpg/melon/resize/120/quality/80/optimize',
#   202718),
#  ('94위',
#   'Love wins all',
#   '아이유',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/04/142/11404142_20240220141548_500.jpg/melon/resize/120/quality/80/optimize',
#   48910),
#  ('95위',
#   '하루 하루',
#   'BIGBANG (빅뱅)',
#   'https://cdnimg.melon.co.kr/cm/album/images/003/92/870/392870_500.jpg/melon/resize/120/quality/80/optimize',
#   122505),
#  ('96위',
#   'STYLE',
#   'Hearts2Hearts (하츠투하츠)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/118/58/555/11858555_20250618105530_500.jpg/melon/resize/120/quality/80/optimize',
#   65966),
#  ('97위',
#   '오늘만 I LOVE YOU',
#   'BOYNEXTDOOR',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/85/070/11685070_20250106111631_500.jpg/melon/resize/120/quality/80/optimize',
#   190061),
#  ('98위',
#   'Magnetic',
#   '아일릿(ILLIT)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/114/50/069/11450069_20240325110702_500.jpg/melon/resize/120/quality/80/optimize',
#   75498),
#  ('99위',
#   'REBEL HEART',
#   'IVE (아이브)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/116/89/783/11689783_20250203110601_500.jpg/melon/resize/120/quality/80/optimize',
#   74538),
#  ('100위',
#   '시작의 아이 ❍',
#   '박다혜, 마크툽 (MAKTUB)',
#   'https://cdnimg.melon.co.kr/cm2/album/images/120/12/550/12012550_20250807172740_500.jpg/melon/resize/120/quality/80/optimize',
#   90966)]

# %%
import csv
import os

# %%
base_path = r"E:\kdt_0900_sal\python\resource"
file_name = r"melon_rank.csv"

file_path = os.path.join(base_path, file_name)
file_path
# Out:
# 'E:\\kdt_0900_sal\\python\\resource\\melon_rank.csv'

# %%
with open(file_path, 'w', newline="", encoding="utf-8-sig") as f:
    writer = csv.writer(f)

    writer.writerow(["순위", "곡제목", "가수", "앨범표지", "좋아요수"])
    writer.writerows(melon_rank)

# %% [markdown]
# ## 알라딘 웹 크롤링 데이터 수집 예제
# - https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1
# - "책 제목", "가격", "별점"을 수집하는 코드 작성 후 제출

# %%
import requests
from bs4 import BeautifulSoup as bs
import json

aladin_url = "https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1"
response = requests.get(aladin_url, headers=headers)
aladin_soup = bs(response.text, "html.parser")
# aladin_soup

# 책 제목
titles = aladin_soup.select(".bo3")
title_list = list(map(lambda tag: tag.text, titles))
print(f"제목\n{title_list}")
print()

# 원가
price = aladin_soup.select(".ss_book_box table table .ss_book_list:first-child li")
price_list = [li.text.split("→")[0].strip().replace("원", "") for li in price[3::5]]
print(f"원가\n{price_list}")
print()

# 할인가
discount = aladin_soup.select("em")
discount_list = list(map(lambda tag: tag.text.replace("원", ""), discount))
print(f"할인가\n{discount_list}")
print()

# 별점
scores = aladin_soup.select(".star_score")
score_list = list(map(lambda tag: tag.text, scores))
print(f"별점\n{score_list}")
print()

aladin_info = list(zip(title_list, price_list, discount_list, score_list))
print(f"알라딘리스트\n{aladin_info}")
# Out:
# 제목
# ['세네카, 오늘을 빼앗기고 있는 당신에게', '그랬다고 적었다', '한국사 이상현상 연구원', '싯다르타', '백야 (먼슬리 클래식)', '카구라바치 11 (더블특전판)', '수족관', '트렌드 코리아 2027', '찌니주의보', '서리꽃 세트 - 전2권 (초판 한정 케이스 + 조정래 작가노트)', '오뒷세이아', '호프 끝장', '빵충 사육 준수 사항', '오뒷세이아 (알라딘 리커버 특별판)', '모순', '테오', '칵테일을 마시는 철학자들', '2026 큰별쌤 최태성의 별★별한
# [('세네카, 오늘을 빼앗기고 있는 당신에게', '18,000', '16,200', '8.7'), ('그랬다고 적었다', '17,000', '15,300', '9.2'), ('한국사 이상현상 연구원', '22,000', '10,710', '9.2'), ('싯다르타', '8,000', '19,800', '9.1'), ('백야 (먼슬리 클래식)', '14,500', '15,840', '10.0'), ('카구라바치 11 (더블특전판)', '6,500', '7,200', '10.0'), ('수족관', '17,700', '5,040', '6.4'), ('트렌드 코리아 2027', '22,000', '13,050', '7.3'), ('찌니주의보', '16,800', '9,180', '9.6'), ('서리꽃 세트 - 전2권 (초판 한정 케이스 + 조정래 작가노트)', '40,000', '5,850', '9.5'), ('오뒷세이아', '25,000', '15,930', '9.8'), ('호프 끝장', '16,800', '19,800', '9.8'), ('빵충 사육 준수 사항', '16,800', '15,120', '9.7'), ('오뒷세이아 (알라딘 리커버 특별판)', '33,000', '12,100', '9.6'), ('모순', '13,000', '36,000', '9.1'), ('테오', '21,000', '22,500', '9.8'), ('칵테일을 마시는 철학자들', '26,000', '15,750', '8.9'), ('2026 큰별쌤 최태성의 별★별한국사 한국사능력검정시험 심화(1, 2, 3급) 상', '19,000', '15,120', '7.3'), ('신경 끄기의 기술 (한교동 에디션)', '19,000', '15,120', '9.0'), ('기쁨에도 슬픔에도 아랑곳없이', '22,000', '12,060', '9.0'), ('브람스를 좋아하세요...', '10,000', '29,700', '8.8'), ('데미안', '8,000', '22,500', '8.8'), ('안녕, 피터팬', '22,000', '11,700', '9.8'), ('절창 (20만 부 기념 화이트 에디션)', '18,000', '18,900', '7.9'), ('2026 큰별쌤 최태성의 별★별한국사 한국사능력검정시험 심화(1, 2, 3급) 하', '18,500', '15,300', '8.6'), ('에그박사 19', '16,800', '23,400', '10.0'), ('브레인 악셀', '22,000', '18,000', '10.0'), ('노무현 평전', '49,500', '17,100', '9.2'), ('찰리 멍거 바이블 완결판', '30,000', '17,100', '10.0'), ('오디세이아 (국내 유일 명화 104점 수록 완역본)', '27,000', '19,800', '10.0'), ('사죠 리히토의 아버지와 그의 부하 상.하 세트 - 전2권', '38,000', '9,000', '10.0'), ('데뷔 못 하면 죽는 병 걸림 5부 초판 한정 굿즈박스 세트 - 전4권', '144,000', '6,300', '10.0'), ('마음의 어휘력', '16,800', '7,200', '9.4'), ('눈 내리는 삼일포', '18,000', '5,040', '7.7'), ('문해내공', '25,000', '19,800', '10.0'), ('타몬 군 지금 어느 쪽?! 14', '7,000', '13,860', '9.5'), ('니체의 초월자', '16,900', '16,200', '8.0'), ('ETS 토익 정기시험 기출문제집 1000 Vol. 5 Reading (리딩)', '22,000', '11,340', '10.0'), ('처음 읽는 그리스 로마 신화 15', '16,800', '16,650', '9.5'), ('코스모스 (100만 부 기념판)', '22,000', '15,120', '10.0'), ('ETS 토익 정기시험 기출문제집 1000 Vol. 5 Listening (리스닝)', '22,000', '19,800', '9.1'), ('처음 읽는 삼국지 5', '16,800', '44,550', '9.8'), ('이상한 지도', '18,800', '35,640', '9.5'), ('녹색 절벽의 신자들', '19,000', '27,000', '9.0')]

# %% [markdown]
# ## 셀레니움(Selenium)
# - 웹 브라우저를 자동으로 제어할 수 있는 오픈소스다.
# - 웹 애플리케이션을 테스트하거나 크롤링하기 위해 사용하는 자동화 도구이다.
# - CSR으로 동작하는 사이트들의 동적인 데이터를 요청하여 크롤링 할 수 있게 한다.
# - [셀레니움 링크](https://www.selenium.dev/documentation/)

# %%
import selenium
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
chrome = Chrome()

google_url = "https://www.google.com/"

chrome.get(google_url)

# %%
search_bar = chrome.find_element(By.CLASS_NAME, "gLFyf")
print(search_bar)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="03cc4962ca013ee29ea80e3fae844233", element="f.B8A8E1CC39C300FC97E63825EEB4EC86.d.CC6322411653BE62776534E6C8F0F718.e.2")>

# %%
search_bar.send_keys("고양이")
time.sleep(3)

search_bar.send_keys(Keys.RETURN)

# %%
chrome.back()

# %% [markdown]
# ## user-agent 설정

# %%
from selenium.webdriver.chrome.options import Options

# %%
options = Options()

user_agent = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"}
options.add_argument(f"user-agent={user_agent}")

chrome = Chrome(options = options)

# %%
url = "https://comic.naver.com/webtoon/detail?titleId=758037&no=260&week=mon"
chrome.get(url)

# %%
# _10hlbxo5 t70z0u2
recent_apply_btn = chrome.find_elements(By.CLASS_NAME, "_10hlbxo5")[1]
recent_apply_btn.click()

# %%
# _root_bkcrx_1 eE2Vs
more_btn = chrome.find_element(By.CLASS_NAME, "eE2Vs")
more_btn.click()

# %%
webtoon_soup = bs(chrome.page_source, "html.parser")

# %%
# webtoon_soup

# 댓글 사용자
[i.text for i in webtoon_soup.select("._name_gaqrg_49")]
# Out:
# ['한창PnT(plyw****)',
#  'qet(qetu****)',
#  'ahd(ahdz****)',
#  'Iamgroot(lanc****)',
#  'hai(hair****)',
#  '파천검희와사귀고싶따(leee****)',
#  '장태규(wkde****)',
#  'atom(silv****)',
#  '우왕(drea****)',
#  'SMIN(tmda****)',
#  'you(youk****)',
#  'min(minw****)',
#  '행젤군(dort****)',
#  '크릉크릉(bu****)',
#  '죽인다(godq****)',
#  'Avalon(mine****)',
#  '조중동폐간(imso****)',
#  'y3ds****(y3ds****)',
#  '리프햄(whit****)',
#  '아기상호뚜루룹뚜루(munj****)',
#  'tnd(tndd****)',
#  'sr_(sr_2****)',
#  'soosoo(soos****)',
#  'bae(baeb****)',
#  'min(minj****)',
#  '2ha(2haj****)',
#  '서제(josh****)',
#  'dltprPxmfjr12(qogk****)',
#  'yeo(yeon****)',
#  '롯데월드(hw****)',
#  'adc(adcg****)',
#  'ksh(ksh6****)',
#  '꿈뜰(hyen****)',
#  '꿈뜰(hyen****)',
#  '영웅본색종이(kt****)',
#  'ssr(ssr3****)',
#  '취미(yc11****)',
#  'yuj(yuji****)',
#  '치쿤치쿤(opki****)',
#  'rjs(rjs4****)']

# %% [markdown]
# ## 스크롤 제어

# %%
# 스크롤 다운
chrome.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %%
# 스크롤 맨 위로
chrome.execute_script("window.scrollTo(0,0)")

# %% [markdown]
# ## velog 크롤링

# %%
options = Options()
user_agent = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36"}
options.add_argument(f"user-agent={user_agent}")

chrome = Chrome(options = options)

velog_url = "https://velog.io/"
chrome.get(velog_url)
time.sleep(5)

recent_btn = chrome.find_elements(By.CLASS_NAME, "HomeTab_tab__viwzb")[1]
recent_btn.click()
time.sleep(5)

for i in range(2):
    chrome.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(5)

velog_soup = bs(chrome.page_source, "html.parser")

# %%
# velog_soup

# %% [markdown]
# #### 실습) velog의 게시글 제목, 내용, 작성자를 각 리스트에 담아서 zip으로 묶기
#
# [("제목", "내용", "작성자"), ...]

# %%
titles = velog_soup.select(".PostCard_h4__6dTLA")
title_list = list(map(lambda tag: tag.text, titles))
print(f"제목\n{title_list}")
print()

texts = velog_soup.select(".PostCard_descriptionWrapper__UQSKA")
text_list = list(map(lambda tag: tag.text, texts))
print(f"내용\n{text_list}")
print()

users = velog_soup.select(".PostCard_userInfo__Cu1X5")
user_list = list(map(lambda tag: tag.text, users))
print(f"작성자\n{user_list}")
print()

velog_info = list(zip(title_list, text_list, user_list))
print(f"벨로그리스트\n{velog_info}")
# Out:
# 제목
# ['Kubernetes Namespace와 Service 정리', '2장. 자바의 절차적/구조적 프로그래밍', '1-.', '9. 단위 테스트', '8. 경계', '7. 에러 처리', '6. 객체와 자료구조', '5. 형식 맞추기', '4. 주석', '3. 함수', '2. 의미있는 이름', '10. 클래스', '3장, 카프카 디자인', 'Hello, Velog', '[DirectX12] 16.2 레이트레이싱 그림자 실습', '내 머리는 *RAM*이 되.', 'CDN(Content Delivery Network, 콘텐츠 전송 네트워크)', '크롤링과 네트워크 원리의 이', '[] 의료영상(MRI)', '🌀 [게임 기획] 뱀서류 X 슬더슬 하이브리드 원소 조합 시스템 기획서 (1편)', 'LG CNS AI Campus KG | LCEL과 Pydantic을 활용한 LLM 구조화 출력 | 09.09', '운영 k8s cluster 구성(1)', '동기(Sync)와 비동기(Async) 가장 쉽게 이해하기 (feat. 자바스크립트)', 'qr code', '[Building CariCue #11] 기능보다 중요한 건 이해 가능성: CariCue v0.1.1이 남긴 제품 인사이트', 'Bash 변수는 왜 "$name"처럼 큰따옴표로 감싸야 할까?', '26. 09. 09. (수) - 2', 'tsconfig의 compilerOptions에서 deprecated 타입 에러가 발생할 때', '[Kubernetes #13] 배포 전략 — Recreate · RollingUpdate · Blue-Green · Canary', 'tmp', 'tmp', 'AWS CloudFormation으로 VPC + Public/Private EC2 구성해보기', 'LLM과 Ollama', '리눅스마스터 2급 | IP 주소 · 서브넷 계산 총정리', 'AI를 활용한 롤(LoL) 실시간 승률 예측 및 맞춤형 밴픽(Pick/Ban) 추천 서비스', '[Setting] Ubuntu 22.04 Docker 환경 및 GPU 환경 세팅하기', 'JavaScript(20260909)', '프론트엔드 정리 노트 - Typescript', 'Daily-Q&A 06. GC(Garbage Collection)는 어떤 원리로 동작하며, 힙 메모리 영역은 어떻게 구성되어 있나요?', 'LLM-Wiki란?', '웹 통신 파헤치기: HTTP의 한계부터 웹소켓, SSE, WebRTC까지', '세로 읽기', 'tmp', 'Spring Core 2: Bean은 어떻게 등록되고 주입될까?', '야구 kbo 기아 타이거즈', '주제를 선택한 이유', 'Bash 변수에는 왜 자료형을 쓰지 않을까? 그리고 a = 1의 공백은 왜 안 될까?', 'AI를 활용한 영양 성분 정보 서비스 기획 및 전망', '26S09a', 'FNF게임의 음악', '누구나 쓸 수 있는 이력서 작성방법', '[투빅스 4주차 정규세션] GenAI', 'MLOps', 'ufc와 나의 경험', '스페이스x의 스타링크 ', 'Code 요점 정리 ', 'React 프로젝트의 하드코딩 메뉴 데이터를 MySQL + Express API로 전환하기', '개인 프로젝트 소개: 바이브코딩으로 웹 게임 만들기', '프로젝트 관리 도구', '#!/bin/sh는 왜 첫 줄에 쓸까? Shebang이 필요한 이유', '접두사인지 확인하기', '『IT 엔지니어를 위한 네트워크 입문』(4장)', '시퀀스', '파일 크기 제한으로 시작된 Tomcat 요청 본문 계층 탐구', '[PM 독서 #03] 일정은 마감일이 아니라 협업 도구다', '넥토리얼 지원', 'Stanford CS224N - Lecture 5 : Language Models and Recurrent Neural Networks', '[플레이데이터 SK네트웍스 Family AI 캠프 36기] DAY24 (2026.09.08)', '# [플레이데이터 SK네트웍스 Family AI 캠프 36기] DAY23 (2026.09.07)', '[Spring Security(9주차)]우리 필터가 인증했다는 걸 Spring Security에게 알려주기', '이미지 생성 모델', '문자열의 앞의 n글자', 'Day 12 - 26.09.09', 'Java 기초 — 얕은 복사와 깊은 복사의 차이', '강한 일관성(Strong) vs 최종 일관성(Eventual)', '아이디어를 만드는 크리에이티브 기법', 'ABS Challenge in mlb', '[Building CariCue #10] 배포된 AI 서비스는 어떻게 안전하게 수정할까: Beta v0.1.1 개선과 배포 과정', '딥러닝 기초 - DataSet', '[DP/WEEK3] extra - LeetCode 123. Best Time to Buy and Sell Stock III', '사전미션4 [ 워밍업 - 그릿(Grit) ] 재능있는 사람보다 무서운건 계속하는 사람', 'Git 개발자 취업 면접 대비 핵심 정리', '[Pro D6] 태양광 발전 단지 관제 시스템', 'Git 명령어 총정리', '정처기 실기 3일차', 'Ubuntu 실습(7)', '정처기 실기 2일차', '[ 졸업작품 기록 (56) ]', 'how Hawk-Eye works', '[ 졸업작품 기록 (55) ]', 'AIO 프리코스 1일차 학습회고 ㅣ 파이썬 기초 문법 정리', 'Cache vs Message Queue', '바로가기(.LNK), Jumplist, Prefetch, MUICache, AmCache & ShimCache 개념', '2514. Count Anagrams', 'how gpt answers question', '[ 포트폴리오 ] 메챠 카멜레온 AR', '[SmartFactory AGV] 디버깅 지옥에서 살아남기 — Server, Unity, Vision, ESP32', '실기기 결제 검증, dSYM 자동 생성, 스토어 스크린샷·출시노트 준비, Android 구글 로그인 Play 서명 키 불일치 추적, 다운로드 언어 선택 UI, 뒤로가기 두 번 종료, 홈 안내 팝업, 코치마크 위치 보정, 회원가입 이메일 자동 로그인, 마이페이지 정리, 업로드 임시저장', '정보처리기사 필기 합격 수기', '2026.09.09 1일 1로그', 'KT-A Bigproject / 수료', '2026.09.08 1일 1로그', "2화, 어른들이 줄인 것은 경쟁이 아니라 '만회할 기회'였다", '260909(Wed) Salesforce Admin(ADX201) 시험 공부 - 13', '[flow-erd] motivation/Challenge/Novelty', '[DirectX12] 16.1 레이트레이싱', '$MFT, $LogFile, $UsnJrnl 개념', '웹개발기초 2주차 수업', '[SmartFactory AGV] Encoder 값은 정상인데 진행방향은  대각선?', '26.09.09(수) 웹개발기초-전소영', '260909(수요일) 웹개발 기초 수업', '123', '260909', '웹개발기초 260909', '🎮 Project : Raid - Combat Attack Ability 리팩토링', '오늘 수업..', 'DAY 27 : 개인 프로젝트 — view (1)', '웹 개발 기초 12분반 수업일지', '📕\xa04. 프리 프로덕션 (I)', 'Windows 포렌식, 레지스트리', '[Kubernetes #12] 헬스 체크와 Pod 생명주기 — Liveness · Readiness · Startup Probe, initContainer, Graceful Shutdown', '전설의 아담 전담', ' 마이크로프로세서 핵심: 인터럽트(Interrupt) 구조와 원리', '개쩌는 오픈소스 영상편집기', 'ATmega128 심화: I/O 레지스터 복합 제어 및 회로 안정화', '입력과 출력은 문제에 주어진 형식이 아니다', '제약 조건은 문제 끝에 붙은 참고 사항이 아니다', '예제 테스트를 통과했다고 문제가 해결된 것은 아니다', 'AI 에이전트가 대체 뭐길래? 챗봇이랑 뭐가 다른지 5분 만에 정리', 'STM32 부팅 과정', '프론트엔드 정리 노트 - Tanstack query' ...
#
# 내용
# ['Kubernetes를 공부하다 보면 Namespace와 Service는 거의 빠지지 않고 등장한다.둘 다 Kubernetes 리소스를 관리할 때 자주 사용하는 개념이지만 역할은 전혀 다르다.Namespace는 클러스터 내부의 리소스를 논리적으로 구분한다.Service는...', '(2024-02-28 에 작성된 포스트입니다.)\n\n2장. 자바의 절차적/구조적 프로그래밍\n\n 일반적인 프로그램은 실행 시 메모리 영역을 `코드 실행 영역`과 `데이터 저장 영역`으로 나누어 사용한다.\n 객체 지향 프...', '(2024-02-28 에 작성된 포스트입니다.)\n\n1장. 개요\n\n 어셈블리 언어는 각 실행 환경별로 다른 소스 코드를 작성해야 했지만, C로 작성한 소스는 동일한 소스 하나로 실행 환경에 적합한 컴파일러를 통해 실행...', '(2024-03-24 에 작성된 포스트입니다.)\n\n9. 단위 테스트\n\nTDD 법칙 세 가지\n\n1. 실패하는 단위 테스트를 작성할 때까지 실제 코드를 작성하지 않는다.\n2. 컴파일은 실패하지 않으면서 실행이 실패하는 ...', '(2024-03-24 에 작성된 포스트입니다.)\n\n본 챕터에서 논하는 경계는 `외부 API, 라이브러리, 패키지와 내부 소스 코드 간의 경계`를 의미하는 듯 하다.\n\n<br/>\n\n외부 코드 사용하기\n\n- 인터페이스 ...', '(2024-03-24 에 작성된 포스트입니다.)\n\n- 오류보단 예외를 사용해라.\n\n- UncheckedException를 사용하자. CheckedException은 좋은 아이디어 같았지만, 객체 상속 과정에서 하위 ...', '(2024-03-24 에 작성된 포스트입니다.)\n\n와 진짜 하나도 모르겠다. 일단 저자가 말하는 객체와 자료구조가 각각 무엇을 의미하는지 모르겠다.\n\n내용으론 캡슐화에 대해 논하고, 뭐에선 어떻고 뭐에선 어떻다 하는...', '(2024-03-23 에 작성된 포스트입니다.)\n\n코드 형식은 중요하다!\n\n- 너무 중요해서 융통성 없이 맹목적으로 따르는 것은 지양해야 한다. 코드 형식은 의사소통의 일환임을 인지해야한다.\n\n- 오늘 구현한 코드의...', '(2024-03-24 에 작성된 포스트입니다.)\n\n나쁜 코드에 주석을 달지 마라. 새로 짜라.\n\n<br/>\n\n- 주석은 잘 쳐줘봐야 필요악이다. 믿어선 안되고 널럴하게 대해선 안 된다.\n\n- 코드로 의도를 표현하지 ...', '(2024-03-24 에 작성된 포스트입니다.)\n\n별 거지같은 함수와 앵간 이해되는 함수는 들이는 노력에 비해 훨씬 큰 차이를 만들어낸다.\n\n- 작게 만들어라! 함수를 만드는 첫째 규칙은 작게. 둘 째 규칙은 더 작...', '(2024-03-24 에 작성된 포스트입니다.)\n\n- 의도가 분명한 이름을 지어야 한다. \n\n- 따로 주석이 필요한 코드라면 의도를 분명히 드러내지 못한 거다. (그… 다 그런 건 아니라고 생각한다. 다만 마땅히 지...', '(2024-03-24 에 작성된 포스트입니다.)\n\n클래스는 작아야 한다.\n\n- `클래스가 충분히 작다.` 의 기준은 해당 클래스가 가지고 있는 책임이 얼마나 다양하냐에 따라 다르다.\n\n- 클래스의 이름은 해당 클래스...', '(2024-03-31 에 작성된 포스트입니다.)\n\n\n3장, 카프카 디자인\n\n3장, 카프카 디자인\n\n*\n\n 카프카는 애초부터 실시간 로그 집계 같은 대용량 데이터 처리를 염두에 두고 만들어졌으며, 배치 전송, 파티션,...', '벨로그 첫시작\n원래는 네이버 블로그를 개발 일지처럼 사용해 보려고 했다. 그런데 어쩌다 보니 개발 관련 글보다는 프로그래머스나 백준 문제를 풀고 정리한 코테 공부 기록이 주가 되어버렸다. 물론 코테 공부 기록을 남기는 것도 좋았지만, 내가 처음 생각했던 블로그의 모습과...', 'https://github.com/rladuddbs/YYEngine/releases/tag/%EB%A0%88%EC%9D%B4%ED%8A%B8%EB%A0%88%EC%9D%B4%EC%8B%B1(%EA%B7%B8%EB%A6%BC%EC%9E%90)실습 코드앞 글에서 ...', '주기억장치&보조기억장치&캐시메모리에 대해서 알아보자....', 'CDN(Content Delivery Network, 콘텐츠 전송 네트워크)은 물리적으로 분산된 여러 대의 캐시 서버(Edge Server)를 거점마다 두고, 사용자와 가장 가까운 위치에서 콘텐츠를 전송해 주는 분산 네트워크 기술입니다.서버가 미국 오레곤에만 있다면 한...', '1\\. 주소 찾기(DNS 조회)사용자가 브라우저 주소창에 naver.com을 입력하면, 컴퓨터는 이 문자열을 네이버 서버의 고유 IP 주소로 바꾸어야 합니다. 브라우저가 자신의 로컬 캐시에 주소가 있는지 확인, 없으면 운영체제(OS) 캐시, 그래도 없으면 통신사(ISP...', '실습...', "전통적인 뱀서류(Vampire Survivors)의 무한 핵앤슬래시 재미에 '슬레이 더 스파이어(Slay the Spire)'의 스테이지 기반 덱빌딩 시스템을 결합한 하이브리드 로그라이크 게임 기획서입니다.초반의 지루함을 없애는 스타팅 선택 및 해금, 회차 플레이의 원...", 'LCEL(LangChain Expression Language)은 프롬프트 템플릿, 언어 모델, 출력 파서 등을 파이프 연산자(|)로 연결하여 하나의 실행 체인을 만드는 선언적 파이프라인 문법이다.각 단계마다 데이터의 형태가 달라진다.예를 들어:결국 최종적으로 문자열을...', '기존 cluster 대신 새로운 cluster를 구성해보자...', '가장 직관적인 비유는 카페 주문 방식입니다.손님 A가 카운터에서 복숭아 아이스티를 주문합니다.직원은 주문을 받자마자 얼음을 푸고, 티를 타고, 뚜껑을 덮어 손님 A에게 건넵니다.손님 A가 음료를 손에 쥐기 전까지, 뒤에 서 있는 손님 B는 주문조차 하지 못하고 하염없이...', 'code의 인덱스를 어떻게 받을까 생각을 해봤다. for문으로 code의 길이만큼 설정하면 인덱스로 취급되지 않을까 생각했다. 그리고 조건문으로 조건을 검사하고 통과한 코드의 값을 answer 에 더하면 문제가 해결되었다....', '\n\nCariCue를 처음 만들기 시작했을 때의 질문은 비교적 단순했습니다.\n\n> 채용공고를 찾는 것보다, 실제로 지원할지 판단하는 과정이 더 어렵지 않을까?\n\n여기에서 시작해\n\n공고 분석 구조를 만들고,\n\n사용자의 Career Context를 정의하고,\n\nAI와 Rul...', '이전에는 Bash에서 변수를 선언할 때 왜처럼 = 앞뒤에 공백을 넣으면 안 되는지 정리했다.Bash에서 공백은 단순히 코드를 보기 좋게 만드는 여백이 아니라 명령어와 인자를 구분하는 중요한 기준이었다.그런데 변수를 조금 더 사용하다 보니 또 하나 궁금한 점이 생겼다.보...', '탐욕...', '😵\u200d💫😵\u200d💫😵\u200d💫...', '\n1. 네 가지 전략\n\n| | Recreate | RollingUpdate | Blue-Green | Canary |\n|---|---|---|---|---|\n| 방식 | 전부 내리고 전부 올림 | 하나씩 올리고 하나씩 내림 | 신버전을 통째로 옆에 띄우고 트래픽을 한 ...', '```\n<%@Language="VBScript" CODEPAGE="65001" %>\n<%\n\'---------------------------------------------------------------------...', '&lt;%@Language="VBScript" CODEPAGE="65001" %>&lt;%\'-----------------------------------------------------------------------\'  index_test.asp  -  index....', 'CloudFormation...', 'LLM은 대규모 텍스트 데이터를 학습해 언어를 이해하고 생성할 수 있는 인공신경망 모델입니다. 문장의 다음 단어를 예측하는 방식으로 학습되며, 이 단순한 원리가 대규모 데이터와 ...
#
# 작성자
# ['by 김감자의 블로그', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by real-dev', 'by onnnnn', 'by Kim YY', 'by 이윤재', 'by JuHee Kim', 'by 쥼마 성장기', 'by 방수정', 'by jaewon lee', 'by Yunji', 'by Sbae', 'by JuHee Kim', 'by 개발조개', 'by MSMoon', 'by 둔감자', 'by 안현', 'by 장유진', 'by 솔키', 'by 허시영', 'by 허시영', 'by 민영', 'by kwondodu', 'by lseonhye', 'by 백민', 'by Miniwini', 'by 유능한', 'by Alpha, Orderly', 'by Taewoo Han', 'by John Corner', 'by JuHee Kim', 'by 개발조개', 'by 허시영', 'by 김윤미', 'by 윤지환', 'by AI/학생/임수현', 'by 둔감자', 'by 백민', 'by QK', 'by 최준현', 'by lemon', 'by JungWon Kong', 'by soo', 'by wndmscks', 'by AI/학생/강병진', 'by 황성보', 'by 박소현', 'by Artem', 'by 이원빈', 'by 둔감자', 'by 개발조개', 'by 전희준', 'by 다니엘', 'by 이건선', 'by 한장맨', 'by 도토코', 'by 정언', 'by 안효원', 'by 안효원', 'by Leo Lee', 'by Mag', 'by 개발조개', 'by 서코딩', 'by @TSP', 'by 킴퀼', 'by Mag', 'by 몰입의 즐거움을 아는 자유로운 영혼', 'by MSMoon', 'by Yujin Jung', 'by 가나지', 'by 김지혜', 'by lseonhye', 'by WTS', 'by lseonhye', 'by BTY', 'by zeusqoi', 'by BTY', 'by 박태근', 'by 몰입의 즐거움을 아는 자유로운 영혼', 'by 박태근', 'by 박두잇', 'by 킴퀼', 'by Yan', 'by 이채원', 'by 몰입의 즐거움을 아는 자유로운 영혼', 'by IANN', 'by H_Hyun', 'by 노영택', 'by SeungHyeon', 'by J8rlChik', 'by Mini', 'by J8rlChik', 'by 안토니오', 'by yujinxlin', 'by ad_official', 'by Kim YY', 'by Yan', 'by 정셕', 'by H_Hyun', 'by 전소영', 'by 안은수', 'by 정윤재', 'by nanzang', 'by kjh2651016', 'by 김대겸', 'by qocksgnl4578', 'by Pt J', 'by junwoo Kwon', 'by Game Design Lab', 'by Yan', 'by 솔키', 'by jundambabo', 'by Haru ☁', 'by 허형준', 'by Haru ☁', 'by vx_developer', 'by vx_developer', 'by vx_developer', 'by Jiwon Jung', 'by moonsyu', 'by Alpha, Orderly', 'by Alpha, Orderly', 'by 배묘', 'by Jini', 'by HelloPong', 'by 이재상', 'by JM', 'by MSMoon', 'by 김동건', 'by sw_quokka', 'by @TSP', 'by jagseeun', 'by 대현', 'by 하이솝', 'by jagseeun', 'by 현수', 'by 이도연', 'by Chobby', 'by CH_Y', 'by april846300', '']
#
# 벨로그리스트
# [('Kubernetes Namespace와 Service 정리', 'Kubernetes를 공부하다 보면 Namespace와 Service는 거의 빠지지 않고 등장한다.둘 다 Kubernetes 리소스를 관리할 때 자주 사용하는 개념이지만 역할은 전혀 다르다.Namespace는 클러스터 내부의 리소스를 논리적으로 구분한다.Service는...', 'by 김감자의 블로그'), ('2장. 자바의 절차적/구조적 프로그래밍', '(2024-02-28 에 작성된 포스트입니다.)\n\n2장. 자바의 절차적/구조적 프로그래밍\n\n 일반적인 프로그램은 실행 시 메모리 영역을 `코드 실행 영역`과 `데이터 저장 영역`으로 나누어 사용한다.\n 객체 지향 프...', 'by real-dev'), ('1-.', '(2024-02-28 에 작성된 포스트입니다.)\n\n1장. 개요\n\n 어셈블리 언어는 각 실행 환경별로 다른 소스 코드를 작성해야 했지만, C로 작성한 소스는 동일한 소스 하나로 실행 환경에 적합한 컴파일러를 통해 실행...', 'by real-dev'), ('9. 단위 테스트', '(2024-03-24 에 작성된 포스트입니다.)\n\n9. 단위 테스트\n\nTDD 법칙 세 가지\n\n1. 실패하는 단위 테스트를 작성할 때까지 실제 코드를 작성하지 않는다.\n2. 컴파일은 실패하지 않으면서 실행이 실패하는 ...', 'by real-dev'), ('8. 경계', '(2024-03-24 에 작성된 포스트입니다.)\n\n본 챕터에서 논하는 경계는 `외부 API, 라이브러리, 패키지와 내부 소스 코드 간의 경계`를 의미하는 듯 하다.\n\n<br/>\n\n외부 코드 사용하기\n\n- 인터페이스 ...', 'by real-dev'), ('7. 에러 처리', '(2024-03-24 에 작성된 포스트입니다.)\n\n- 오류보단 예외를 사용해라.\n\n- UncheckedException를 사용하자. CheckedException은 좋은 아이디어 같았지만, 객체 상속 과정에서 하위 ...', 'by real-dev'), ('6. 객체와 자료구조', '(2024-03-24 에 작성된 포스트입니다.)\n\n와 진짜 하나도 모르겠다. 일단 저자가 말하는 객체와 자료구조가 각각 무엇을 의미하는지 모르겠다.\n\n내용으론 캡슐화에 대해 논하고, 뭐에선 어떻고 뭐에선 어떻다 하는...', 'by real-dev'), ('5. 형식 맞추기', '(2024-03-23 에 작성된 포스트입니다.)\n\n코드 형식은 중요하다!\n\n- 너무 중요해서 융통성 없이 맹목적으로 따르는 것은 지양해야 한다. 코드 형식은 의사소통의 일환임을 인지해야한다.\n\n- 오늘 구현한 코드의...', 'by real-dev'), ('4. 주석', '(2024-03-24 에 작성된 포스트입니다.)\n\n나쁜 코드에 주석을 달지 마라. 새로 짜라.\n\n<br/>\n\n- 주석은 잘 쳐줘봐야 필요악이다. 믿어선 안되고 널럴하게 대해선 안 된다.\n\n- 코드로 의도를 표현하지 ...', 'by real-dev'), ('3. 함수', '(2024-03-24 에 작성된 포스트입니다.)\n\n별 거지같은 함수와 앵간 이해되는 함수는 들이는 노력에 비해 훨씬 큰 차이를 만들어낸다.\n\n- 작게 만들어라! 함수를 만드는 첫째 규칙은 작게. 둘 째 규칙은 더 작...', 'by real-dev'), ('2. 의미있는 이름', '(2024-03-24 에 작성된 포스트입니다.)\n\n- 의도가 분명한 이름을 지어야 한다. \n\n- 따로 주석이 필요한 코드라면 의도를 분명히 드러내지 못한 거다. (그… 다 그런 건 아니라고 생각한다. 다만 마땅히 지...', 'by real-dev'), ('10. 클래스', '(2024-03-24 에 작성된 포스트입니다.)\n\n클래스는 작아야 한다.\n\n- `클래스가 충분히 작다.` 의 기준은 해당 클래스가 가지고 있는 책임이 얼마나 다양하냐에 따라 다르다.\n\n- 클래스의 이름은 해당 클래스...', 'by real-dev'), ('3장, 카프카 디자인', '(2024-03-31 에 작성된 포스트입니다.)\n\n\n3장, 카프카 디자인\n\n3장, 카프카 디자인\n\n*\n\n 카프카는 애초부터 실시간 로그 집계 같은 대용량 데이터 처리를 염두에 두고 만들어졌으며, 배치 전송, 파티션,...', 'by real-dev'), ('Hello, Velog', '벨로그 첫시작\n원래는 네이버 블로그를 개발 일지처럼 사용해 보려고 했다. 그런데 어쩌다 보니 개발 관련 글보다는 프로그래머스나 백준 문제를 풀고 정리한 코테 공부 기록이 주가 되어버렸다. 물론 코테 공부 기록을 남기는 것도 좋았지만, 내가 처음 생각했던 블로그의 모습과...', 'by onnnnn'), ('[DirectX12] 16.2 레이트레이싱 그림자 실습', 'https://github.com/rladuddbs/YYEngine/releases/tag/%EB%A0%88%EC%9D%B4%ED%8A%B8%EB%A0%88%EC%9D%B4%EC%8B%B1(%EA%B7%B8%EB%A6%BC%EC%9E%90)실습 코드앞 글에서 ...', 'by Kim YY'), ('내 머리는 *RAM*이 되.', '주기억장치&보조기억장치&캐시메모리에 대해서 알아보자....', 'by 이윤재'), ('CDN(Content Delivery Network, 콘텐츠 전송 네트워크)', 'CDN(Content Delivery Network, 콘텐츠 전송 네트워크)은 물리적으로 분산된 여러 대의 캐시 서버(Edge Server)를 거점마다 두고, 사용자와 가장 가까운 위치에서 콘텐츠를 전송해 주는 분산 네트워크 기술입니다.서버가 미국 오레곤에만 있다면 한...', 'by JuHee Kim'), ('크롤링과 네트워크 원리의 이', '1\\. 주소 찾기(DNS 조회)사용자가 브라우저 주소창에 naver.com을 입력하면, 컴퓨터는 이 문자열을 네이버 서버의 고유 IP 주소로 바꾸어야 합니다. 브라우저가 자신의 로컬 캐시에 주소가 있는지 확인, 없으면 운영체제(OS) 캐시, 그래도 없으면 통신사(ISP...', 'by 쥼마 성장기'), ('[] 의료영상(MRI)', '실습...', 'by 방수정'), ('🌀 [게임 기획] 뱀서류 X 슬더슬 하이브리드 원소 조합 시스템 기획서 (1편)', "전통적인 뱀서류(Vampire Survivors)의 무한 핵앤슬래시 재미에 '슬레이 더 스파이어(Slay the Spire)'의 스테이지 기반 덱빌딩 시스템을 결합한 하이브리드 로그라이크 게임 기획서입니다.초반의 지루함을 없애는 스타팅 선택 및 해금, 회차 플레이의 원...", 'by jaewon lee'), ('LG CNS AI Campus KG | LCEL과 Pydantic을 활용한 LLM 구조화 출력 | 09.09', 'LCEL(LangChain Expression Language)은 프롬프트 템플릿, 언어 모델, 출력 파서 등을 파이프 연산자(|)로 연결하여 하나의 실행 체인을 만드는 선언적 파이프라인 문법이다.각 단계마다 데이터의 형태가 달라진다.예를 들어:결국 최종적으로 문자열을...', 'by Yunji'), ('운영 k8s cluster 구성(1)', '기존 cluster 대신 새로운 cluster를 구성해보자...', 'by Sbae'), ('동기(Sync)와 비동기(Async) 가장 쉽게 이해하기 (feat. 자바스크립트)', '가장 직관적인 비유는 카페 주문 방식입니다.손님 A가 카운터에서 복숭아 아이스티를 주문합니다.직원은 주문을 받자마자 얼음을 푸고, 티를 타고, 뚜껑을 덮어 손님 A에게 건넵니다.손님 A가 음료를 손에 쥐기 전까지, 뒤에 서 있는 손님 B는 주문조차 하지 못하고 하염없이...', 'by JuHee Kim'), ('qr code', 'code의 인덱스를 어떻게 받을까 생각을 해봤다. for문으로 code의 길이만큼 설정하면 인덱스로 취급되지 않을까 생각했다. 그리고 조건문으로 조건을 검사하고 통과한 코드의 값을 answer 에 더하면 문제가 해결되었다....', 'by 개발조개'), ('[Building CariCu ...
