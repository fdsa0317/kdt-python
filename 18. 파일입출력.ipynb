# %%
import os

base_path = r"E:\kdt_0900_sal\python\resource"
file_name = "file_test01.txt"

file_path = os.path.join(base_path, file_name)

print(file_path)
# Out:
# E:\kdt_0900_sal\python\resource\file_test01.txt

# %%
# w: 없으면 생성 있으면 덮어쓰기
f = open(file_path, "w", encoding="utf-8")

f.write("파일 입출력 해보기!\n")
f.write("나 글 좀 쓰는 듯😎")

f.close()

# %%
f = open(file_path, "a", encoding="utf-8")

f.write("파일 입출력 해보기!\n")
f.write("나 글 좀 쓰는 듯😎")

f.close()

# %%
f = open(file_path, "r", encoding="utf-8")
# print(f.read())
# print(type(f.read()))

# 한 줄씩 들고 오기
print(f.readline())
print(f.readline())
print(type(f.readline())) # 값이 없으면 빈 문자열

f.close()
# Out:
# 파일 입출력 해보기!
#
# 나 글 좀 쓰는 듯😎
# <class 'str'>

# %%
f = open(file_path, "r", encoding="utf-8")

while (text := f.readline()):
    print(text)

f.close()
# Out:
# 파일 입출력 해보기!
#
# 나 글 좀 쓰는 듯😎

# %%
try:
    f = open(file_path, "r", encoding="utf-8")
    print(f.readlines())

except Exception as e:
    print(e)

finally:
    f.close()
# Out:
# ['파일 입출력 해보기!\n', '나 글 좀 쓰는 듯😎']

# %% [markdown]
# ## with문
# - resource를 사용한 뒤 자동으로 반납하여 안전하게 관리해주는 문법

# %%
with open(file_path, "w", encoding="utf-8") as f:
    f.write("안녕")
    f.write("하세요")
     # f.close() 모든 행이 실행되고 마지막에 close()가 자동으로 실행

# %% [markdown]
# ## 파일 수정

# %%
foods = ["돈까스", "제육볶음", "김치찌개", "순두부찌개", "된장찌개", "순대국", "센베이"]

file_name = "food_list.txt"
file_path = os.path.join(base_path, file_name)

with open(file_path, "w", encoding="utf-8") as f:
    f.writelines([food + "\n" for food in foods])

# %%
# 읽어오기
with open(file_path, "r", encoding="utf-8") as f:
    foods = f.readlines()
    foods[6] = "삼겹살\n"

print(foods)

with open(file_path, "w", encoding="utf-8") as f:
    f.writelines(foods)
    print(f"{file_name}파일 수정이 완료되었습니다.")
# Out:
# ['돈까스\n', '제육볶음\n', '김치찌개\n', '순두부찌개\n', '된장찌개\n', '순대국\n', '삼겹살\n']
# food_list.txt파일 수정이 완료되었습니다.

# %%
# 돈까스, 된장찌개 삭제

# with open(file_path, "r", encoding="utf-8") as f:
#     foods = f.readlines()
#     foods.pop(0)

# with open(file_path, "w", encoding="utf-8") as f:
#     f.writelines(foods)
#     print(f"{file_name}파일 수정이 완료되었습니다.")

# print(foods)
# Out:
# food_list.txt파일 수정이 완료되었습니다.
# ['제육볶음\n', '김치찌개\n', '순두부찌개\n', '된장찌개\n', '순대국\n', '삼겹살\n']

# %%
# with open(file_path, "r", encoding="utf-8") as f:
#     foods = f.readlines()
#     foods.pop(3)

# with open(file_path, "w", encoding="utf-8") as f:
#     f.writelines(foods)
#     print(f"{file_name}파일 수정이 완료되었습니다.")

# print(foods)
# Out:
# food_list.txt파일 수정이 완료되었습니다.
# ['제육볶음\n', '김치찌개\n', '순두부찌개\n', '순대국\n', '삼겹살\n']

# %%
with open(file_path, "r", encoding="utf-8") as f:
    foods = f.readlines()
    for food in foods:
        if food == "돈까스\n" or food == "된장찌개\n":
            foods.remove(food)

with open(file_path, "w", encoding="utf-8") as f:
    f.writelines(foods)
    print(f"{file_name}파일 수정이 완료되었습니다.")
# Out:
# food_list.txt파일 수정이 완료되었습니다.

# %%
# CSV(Comma Separated Value)
import csv

file_name = "동물미용실.csv"
file_path = os.path.join(base_path, file_name)

with open(file_path, "r", encoding="cp949") as f:
    reader = csv.reader(f)

    header = next(reader)
    for row in list(reader)[:5]:
        print(row)
# Out:
# ['3000000', '300000004920260001', '2026-05-08', '', '영업/정상', '', '', '', '', '0', '', '03082', '대학로 애견카페', 'I', '000', '2026-05-09 23:29:05', '서울특별시 종로구 대학로 **, *층 (연건동)', '', '정상', '0000', '01', '', '200099.032850302    ', '452925.449270507    ', '서울특별시 종로구 연건동 ** ', '2026-05-08 09:22:16']
# ['3000000', '300000004920260003', '2026-08-04', '', '영업/정상', '', '', '', '', '0', '', '03115', '루이살롱(한국반려동물아카데미 부설 펫뷰티 센터)', 'U', '000', '2026-08-07 22:32:50', '서울특별시 종로구 종로 ***, 태정빌딩 *층 (숭인동)', '', '정상', '0000', '01', '0216445919', '201809.67645682     ', '452460.718015096    ', '서울특별시 종로구 숭인동 ***-* 태정빌딩 ', '2026-08-06 09:40:37']
# ['3000000', '300000004920180016', '2018-10-17', '', '취소/말소/만료/정지/중지', '2023-06-14', '', '', '', '0', '', '03113', 'Dog star', 'I', '000', '2026-05-05 22:33:04', '서울특별시 종로구 지봉로 **-*, *층 (숭인동)', '', '말소', '0004', '04', '027424806', '201335.490343284    ', '452532.491900794    ', '서울특별시 종로구 숭인동 **-** ', '2023-11-01 14:42:46']
# ['3000000', '300000004920180017', '2018-10-18', '', '취소/말소/만료/정지/중지', '2023-06-14', '', '', '', '0', '', '03126', '미션코리아', 'I', '000', '2026-05-05 22:33:04', '서울특별시 종로구 대학로 **, *층 (효제동)', '', '말소', '0004', '04', '', '200126.766304313    ', '452265.173517838    ', '서울특별시 종로구 효제동 ***-* ', '2023-06-14 09:42:44']
# ['3000000', '300000004920260002', '2026-06-19', '', '영업/정상', '', '', '', '', '0', '', '03007', '아띠랑', 'I', '000', '2026-06-20 22:32:50', '서울특별시 종로구 진흥로 ***, 인왕빌딩 *층 ***호 (구기동)', '', '정상', '0000', '01', '', '196188.676804345    ', '456211.92274867     ', '서울특별시 종로구 구기동 **-* 인왕빌딩 ', '2026-06-19 09:26:16']

# %%
file_name = "할일목록.csv"
file_path = os.path.join(base_path, file_name)

with open(file_path, "w", encoding="utf-8-sig", newline="") as f:
    writer = csv.writer(f)
    # 첫 줄 제목(열)
    writer.writerow(["날짜", "할일 목록"])
    writer.writerows([("2026-08-28", "퇴실"), ("2026-08-28", "복습"), ("2026-08-28", "잠자기")])

    print(f"{file_name}이 생성되었습니다")
# Out:
# 할일목록.csv이 생성되었습니다
